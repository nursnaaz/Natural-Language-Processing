# %% [markdown]
# # Basics on Information Extraction using Regular Expressions
#
# ## Description
#
# In a previous couple of years, there has been a dramatic shift in usage of general purpose programming languages for information science and machine learning.
#
# This wasn't continuously the case – a decade back this thought would have met plenty of intellectual eyes! This means that additional individuals/organizations have started making use of tools like Python / JavaScript for finding their information wants. This is where Regular Expressions or REGEX become super useful. Regular expressions square measure ordinarily the default means of information improvement and haggling in most of those tools. Be it extraction of specific components of text from websites, creating a sense of Twitter information or making ready your information for text mining – Regular expressions square measure your best bet for all these tasks.
#
# Given their relevancy, it is smart to understand them and use them fittingly.
#
# ## Overview
#
# - Motivation through the use of Regular Expressions for Data cleaning in real time dataset
# - Rundown through available Regular Expressions
# - Exposure to meta operators and their usage
#
# ## Pre-requisite
#
# - Python (along with NumPy and Pandas libraries)
# - Basic knowledge of usage of loops
#
#
# ## Learning Outcomes
#
# - Describing complex patterns in the text
# - Effecting usage of REGEX in search, pattern matching, parsing, filtering of results, etc.,
# - Understanding different error metrics

# %% [markdown]
# ## Chapter 1: Regular expressions and their usage
#
# ### Description:  In this Chapter, we will make use of REGEX to clean the text data obtained trough ***Twitter Crawler***

# %% [markdown]
# ### 1.1 What is Regular Expression and how is it used?
#
# In Simple words, REGEX or Regular expressions are a sequence of characters mainly used to find and replace patterns in a string or file. As I discussed before, they are supported by most of the programming languages like. So, Once learned these could help in many ways (more on this later).
#
# ***We will be making use of a module called "re" in python. Which we need to install and import before making use of them!***

# %% [markdown]
# ### 1.2 What are various methods of Regular Expressions?
# We are going to make use of the ‘re’ package which gives us multiple methods to perform queries on an input string. Here are the most commonly used methods, I will discuss and thereby use in my dataset:
#
#
# 1. re.match()
# 2. re.search()
# 3. re.sub()
# 4. re.split()
# 5. re.findall()
# 6. re.compile()
#
# We will look at them one by one

# %% [markdown]
# ### 1.3 Types of Characters used in REGEX
# Regular expressions use two types of characters:
#
# a) Metacharacters: These characters have a special meaning, similar to * in wild card.
#
# ![download.png](attachment:download.png)
#
# b) Literals (like a,b,1,2…)

# %% [markdown]
# ### 1.4 About the Data
# This is the data of tweets from the Twitter hashtag ***"#Elections2019"*** dated from 01 march to 11 march 2019. This data is obtained using twitter crawler for which the code can be found [here](https://gist.github.com/vickyqian/f70e9ab3910c7c290d9d715491cde44c)
#
# This csv file contains two columns
# - Date_time: The date and time at whcih the tweet was posted
# - Tweet: This is the column which contains the Tweet

# %% [markdown]
# ### 1.5 Data Cleaning
# `Steps we will be doing with REGEX`
# - Extracting Date and time into seperate columns
# - Extracting the Tweet type
# - Extracting the Hash tags
# - Extracting the User tags
# - Removing Special Character
# - Removing Numbers
# - Removing single word characters from the tweets

# %%
import pandas as pd
import numpy as np 
import re

#Reading the Tweet csv file
df = pd.read_csv("Twitter_data.csv",encoding = 'utf-8')

# %%
df.head()
# Out:
#              Date_time                                              Tweet
# 0  2019-03-11 11:12:57  b'RT @arpitajtweets: Just for fun\xf0\x9f\x91\...
# 1  2019-03-11 11:12:51  b'Where is safety,how we safe,this is the situ...
# 2  2019-03-11 11:12:44  b"RT @ManiDevaMS: #DelhiCapitals is not only #...
# 3  2019-03-11 11:12:39  b'RT @VinayDokania: How Indian Journalists com...
# 4  2019-03-11 11:12:37  b'#Elections2019 Dates are finally out. @Bored...

# %% [markdown]
# ### re.split() - Split
# This function helps us to separate string by the occurrences of given pattern.
#
# #### Syntax
# ##### re.split(pattern, repl,  [maxsplit=0])

# %%
#Initialising new columns with name Date and time
df['Date'] = "NA"
df['time'] = "NA"
#seperating Date and time into seperate Columns
for i in df['Date_time']:
    df[['Date','time']] = re.split(r" ",i)

# %%
df.head()
# Out:
#              Date_time                                              Tweet  \
# 0  2019-03-11 11:12:57  b'RT @arpitajtweets: Just for fun\xf0\x9f\x91\...
# 1  2019-03-11 11:12:51  b'Where is safety,how we safe,this is the situ...
# 2  2019-03-11 11:12:44  b"RT @ManiDevaMS: #DelhiCapitals is not only #...
# 3  2019-03-11 11:12:39  b'RT @VinayDokania: How Indian Journalists com...
# 4  2019-03-11 11:12:37  b'#Elections2019 Dates are finally out. @Bored...
#
#          Date      time
# 0  2019-03-10  07:52:48
# 1  2019-03-10  07:52:48
# 2  2019-03-10  07:52:48
# 3  2019-03-10  07:52:48
# 4  2019-03-10  07:52:48

# %%
del df["Date_time"]

# %% [markdown]
# ### re.sub() - Search & Replace
# This is one of the most important 're' methods, where we search for the pattern and replace it in the string.
#
# #### Syntax
# ##### re.sub(pattern, repl, string)

# %%
for i in range(0,len(df['Tweet'])):
    #Removing "b'" and "b"" from the Tweet column
    df['Tweet'][i]= re.sub(r"b\'" ,'',df['Tweet'][i])
    df['Tweet'][i]= re.sub(r"b\"",'',df['Tweet'][i])

# %%
df.head(10)
# Out:
#                                                Tweet        Date      time
# 0  RT @arpitajtweets: Just for fun\xf0\x9f\x91\x8...  2019-03-10  07:52:48
# 1  Where is safety,how we safe,this is the situat...  2019-03-10  07:52:48
# 2  RT @ManiDevaMS: #DelhiCapitals is not only #in...  2019-03-10  07:52:48
# 3  RT @VinayDokania: How Indian Journalists come ...  2019-03-10  07:52:48
# 4  #Elections2019 Dates are finally out. @BoredBr...  2019-03-10  07:52:48
# 5  RT @RamMNK: TDP workers, next 30 days month ar...  2019-03-10  07:52:48
# 6  RT @sunetrac: anyone else confused with the wa...  2019-03-10  07:52:48
# 7  RT @streetbilionare: My Bauchi People, Victory...  2019-03-10  07:52:48
# 8  RT @VinayDokania: How Indian Journalists come ...  2019-03-10  07:52:48
# 9  RT @moneycontrolcom: #ElectionsWithMC | A day ...  2019-03-10  07:52:48

# %% [markdown]
# ### re.match() - Match
# This function attempts to match RE pattern to string and contains some optional flags.
#
# #### Syntax
# ##### re.match(pattern, string)
#
# The re.match function will return a match object on a successful match and None on failure. To print the actual matched string we will be using method group. The "r" at the start of the string will designate to the python raw string.

# %%
#those with RT are retweets while those with T are  tweets.
#initializing new column
df['Tweet_type'] = "NA"
for i in range(0,len(df['Tweet'])):
    result = re.match('RT',df['Tweet'][i],re.I|re.M) #re.I and re.M are modifiers and these are explained in upcoming sessions 
    if result:
        print( "match --> %s " % result.group())
        df['Tweet_type'][i] = result.group()
    else:
        print("None")
        #Those columns without RT are Tweets i.e, 'T'
        df['Tweet_type'][i] = "T"
# Out:
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# ...
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# None
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# None
# None
# None
# None
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# None
# match --> RT
# match --> Rt
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# match --> RT
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# None
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# None
# None
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# None
# match --> RT
# match --> RT
# match --> RT
# match --> RT
# match --> RT

# %%
df.head(10)
# Out:
#                                                Tweet        Date      time  \
# 0  RT @arpitajtweets: Just for fun\xf0\x9f\x91\x8...  2019-03-10  07:52:48
# 1  Where is safety,how we safe,this is the situat...  2019-03-10  07:52:48
# 2  RT @ManiDevaMS: #DelhiCapitals is not only #in...  2019-03-10  07:52:48
# 3  RT @VinayDokania: How Indian Journalists come ...  2019-03-10  07:52:48
# 4  #Elections2019 Dates are finally out. @BoredBr...  2019-03-10  07:52:48
# 5  RT @RamMNK: TDP workers, next 30 days month ar...  2019-03-10  07:52:48
# 6  RT @sunetrac: anyone else confused with the wa...  2019-03-10  07:52:48
# 7  RT @streetbilionare: My Bauchi People, Victory...  2019-03-10  07:52:48
# 8  RT @VinayDokania: How Indian Journalists come ...  2019-03-10  07:52:48
# 9  RT @moneycontrolcom: #ElectionsWithMC | A day ...  2019-03-10  07:52:48
#
#   Tweet_type
# 0         RT
# 1          T
# 2         RT
# 3         RT
# 4          T
# 5         RT
# 6         RT
# 7         RT
# 8         RT
# 9         RT

# %% [markdown]
# ### re.search() - Search
# This function performs a searches for first occurrence of pattern within string with optional flags.
#
# #### Syntax
# ##### re.search(pattern, string)
#
# ***Difference between match and Search***:
# Match checks for a match only at the start of the string, while search checks for a match anywhere in the string.

# %% [markdown]
# ### re.compile() - Combine
# We can Regular Expressions into objects, which can be used for pattern matching. It also helps in making the code reusable.
#
# #### Syntax
# ##### re.compile(pattern, repl, string)

# %%
#here the representaions of Retweets may be given as "RT" or "Rt" so lets find out if there are any such instances
for i in range(0,len(df["Tweet_type"])):
    #here we dont specify re.I | re.M as we need to be case specific here
    pattern=re.compile('Rt')
    result=pattern.search(df["Tweet_type"][i])
    if result:
        print(result.group())
        #replace Rt's with RT
        df['Tweet_type'][i]= re.sub(r"Rt" ,r'RT',df['Tweet_type'][i])
# Out:
# Rt
# Rt

# %%
df['Tweet_type'].value_counts()
# Out:
# RT    13207
# T      4682
# Name: Tweet_type, dtype: int64

# %% [markdown]
# ### Modifiers
# In adddition to this there are also a number of modifiers that can be used along with these regular expressions. Those are
# given below:
#
# ![image.png](attachment:image.png)

# %%
#so lets now remove the RT from tweet column which we Search and Replace
for i in range(0,len(df['Tweet'])):
    #This is to remove "b'" and "b"" from the Tweet column
    result = re.match('RT',df['Tweet'][i],re.I|re.M)
    if result: 
        df['Tweet'][i]= re.sub(r"RT" ,'',df['Tweet'][i],re.I|re.M)

# %%
df['Tweet'].head()
# Out:
# 0     @arpitajtweets: Just for fun\xf0\x9f\x91\x8d\...
# 1    Where is safety,how we safe,this is the situat...
# 2     @ManiDevaMS: #DelhiCapitals is not only #indi...
# 3     @VinayDokania: How Indian Journalists come ou...
# 4    #Elections2019 Dates are finally out. @BoredBr...
# Name: Tweet, dtype: object

# %%
df.head(10)
# Out:
#                                                Tweet        Date      time  \
# 0   @arpitajtweets: Just for fun\xf0\x9f\x91\x8d\...  2019-03-10  07:52:48
# 1  Where is safety,how we safe,this is the situat...  2019-03-10  07:52:48
# 2   @ManiDevaMS: #DelhiCapitals is not only #indi...  2019-03-10  07:52:48
# 3   @VinayDokania: How Indian Journalists come ou...  2019-03-10  07:52:48
# 4  #Elections2019 Dates are finally out. @BoredBr...  2019-03-10  07:52:48
# 5   @RamMNK: TDP workers, next 30 days month are ...  2019-03-10  07:52:48
# 6   @sunetrac: anyone else confused with the way ...  2019-03-10  07:52:48
# 7   @streetbilionare: My Bauchi People, Victory D...  2019-03-10  07:52:48
# 8   @VinayDokania: How Indian Journalists come ou...  2019-03-10  07:52:48
# 9   @moneycontrolcom: #ElectionsWithMC | A day af...  2019-03-10  07:52:48
#
#   Tweet_type
# 0         RT
# 1          T
# 2         RT
# 3         RT
# 4          T
# 5         RT
# 6         RT
# 7         RT
# 8         RT
# 9         RT

# %% [markdown]
# ### re.findall()
# It helps to get a list with the result for all matching patterns. It can start searching from the start or from the end. If we will use function findall to search a word or a pattern in the given string it will return a list of all the occurrences of the word/pattern. When it involves searching a string, I would advise you to use re.findall(), as it can work like re.search() and re.match() both.
#
# #### Syntax
# ##### re.findall(pattern, string)

# %%
#Seperating the Hashtags from the Tweets
df['hash_tags'] = "NA"
for i in range(0,len(df['Tweet'])):
    result = re.findall('#[\w]*',df['Tweet'][i])
    if result:
        print( "Hashs --> %s " % result)
        df['hash_tags'][i] = result
    else:
        print("None")
        df['hash_tags'][i] = "None"
# Out:
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# Hashs --> ['#India', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionsWithMC', '#Elections2019']
# Hashs --> ['#NigeriaGovernorship']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionsWithHT']
# None
# None
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# None
# None
# Hashs --> ['#NigeriaDecides2019', '#Elections2019']
# Hashs --> ['#NOTA2019', '#ElectionWar2019', '#ElectionCommission', '#Elections2019', '#ElectionsWithNDTV', '#ElectionCommision']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ARSMUN', '#Elections2019', '#LIVBUR']
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#Elections2019', '#Odisha']
# None
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#NarendraModi', '#ElectionCommission', '#NamoAgain']
# None
# Hashs --> ['#Poll', '#dates', '#clash', '#Ramzan', '#unnecessary', '#row']
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# None
# None
# None
# None
# Hashs --> ['#ElectionsWithMC', '#ArunJaitley']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#Ramgarh']
# Hashs --> ['#JanaSena', '#JSPforNewAgePolitics', '#ElectionDate', '#Elections2019', '#VoteforGlass']
# None
# None
# None
# None
# None
# Hashs --> ['#ARSMUN', '#Elections2019', '#LIVBUR']
# Hashs --> ['#Elections2019', '#daggaparty', '#dagga', '#Politics', '#polticialparties']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#LokSabhaElections2019', '#Assembly']
# None
# Hashs --> ['#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#NamoSaree', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019', '#LokSabhaElections2019', '#17thLokSabha']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019', '#DigitalMarketing', '#strategy']
# None
# None
# Hashs --> ['#India', '#ElectionCommissionOfIndia', '#Elections2019', '#LoksabhaElection', '#LokSabhaElections2019', '#ElectionCommission', '#M']
# Hashs --> ['#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#PhirEkBaarModiSarkar', '#ModiMattome', '#Elections2019', '#Continue', '#']
# Hashs --> ['#ElectionsWithMC', '#Elections2019']
# None
# Hashs --> ['#Centre']
# None
# None
# Hashs --> ['#Elections2019', '#April11']
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# None
# Hashs --> ['#ElectionCommission']
# None
# None
# None
# None
# None
# None
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# Hashs --> ['#Elections2019', '#MeraBoothSabseMazboot', '#ElectionCommi']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#De']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# None
# Hashs --> ['#VoteforModi']
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# Hashs --> ['#India', '#ElectionCommissionOfIndia', '#Elections2019', '#LoksabhaElection', '#LokSabhaElections2019', '#ElectionCommission']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#MollyGambhir', '#WION', '#BhairaviSingh']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#vcan4mumbai']
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# Hashs --> ['#Elections2019', '#KanoDecides2019', '#Kano']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# None
# None
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# None
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Elections2019', '#Quiz']
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# None
# None
# None
# Hashs --> ['#Elections2019', '#leadership']
# Hashs --> ['#Modibhakt']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019', '#Odisha']
# Hashs --> ['#WestBengal', '#JammuAndKashmir']
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#NationalSecurity', '#Elections2019']
# Hashs --> ['#LokalMusic', '#SundayAgidiJollof', '#WeDeyPlay']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Elections2019']
# Hashs --> ['#JustIn']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#NOTA2019', '#ElectionWar2019', '#ElectionCommission', '#Elections2019', '#ElectionsWithNDTV', '#ElectionCommision']
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#KanoDecides2019', '#Kano']
# Hashs --> ['#Modi2019Wave', '#RahulGandhi', '#Elections2019', '#LokSabhaEl']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Elections2019', '#LokSabhaElectio']
# Hashs --> ['#ElectionCommission', '#Elections']
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#watsapp', '#Elections2019', '#LS2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Kejriwal', '#AAP']
# None
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#JANASENARevolution2019', '#Janasena', '#Elections2019']
# None
# None
# None
# None
# Hashs --> ['#BJP', '#loksabha', '#AndhraPradesh']
# Hashs --> ['#LokSabhaElections2019', '#ElectionsWithH']
# None
# Hashs --> ['#MondayMotivaton', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019', '#LokSabhaElections2019', '#17thLokSabha']
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#AndhraPradesh', '#Telangana', '#Elections2019', '#ElectionCommission']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Islam', '#Muslims', '#Elections2019']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#RaGa']
# None
# Hashs --> ['#Elections2019', '#Odisha']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#AntiNationalOpposition', '#Pakistan']
# Hashs --> ['#600CroreVoter', '#564Seats', '#ABPnews', '#ModiLies', '#Mo']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019', '#LokSabhaElections2019', '#17thLokSabha']
# None
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# None
# None
# Hashs --> ['#ECI', '#rings', '#the', '#bell', '#Parties', '#gearing', '#up', '#LSpoll']
# None
# None
# Hashs --> ['#Elections2019', '#ElectionResul']
# Hashs --> ['#Elections2019', '#KanoDecides2019', '#Kano']
# Hashs --> ['#LoksabhaElections', '#Karnataka', '#Elections2019', '#al']
# Hashs --> ['#600CroreVoter', '#564Seats', '#ABPnews', '#ModiLies', '#Mo']
# None
# Hashs --> ['#LokSabhaElections2019', '#ElectionsWithH']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ISIS', '#ISISBrides']
# None
# Hashs --> ['#ElectionCommission', '#LokSabhaElection2019']
# Hashs --> ['#Ali', '#YSRCP', '#Elections2019', '#AndhraPradeshElections', '#An']
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Karnataka']
# Hashs --> ['#Elections2019', '#Bengal', '#Trinamool']
# Hashs --> ['#EVMs', '#Elections2019', '#ElectionCommission', '#Congress', '#BJP']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#Elections2019', '#KanoDecides2019', '#Kano']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Elections2019', '#ElectionResul']
# Hashs --> ['#Elections2019', '#ElectionResul']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#fullstatehood4delhi']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#Elec']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Elections2019', '#elections', '#GeneralElections2019']
# Hashs --> ['#']
# None
# None
# Hashs --> ['#data', '#socialmedia', '#Elections2019']
# None
# Hashs --> ['#Elections2019', '#PhirEkBaarModiSarkar']
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#Elections2019']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#LokSabhaElections2019', '#ElectionsW']
# None
# None
# Hashs --> ['#TDP', '#NCBN', '#ChandrababuNaidu', '#YSRCP', '#YSJagan']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Ali', '#YSRCP', '#Elections2019', '#AndhraPradeshElections', '#An']
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#CongressPakistanUnited', '#Ele']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#AIMIM', '#']
# None
# Hashs --> ['#Buttigieg', '#Christianity']
# None
# None
# Hashs --> ['#ISIS', '#ISISBrides']
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#India', '#Democracy', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#KanoDecides2019']
# Hashs --> ['#LokSabhaElections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#DemonetisationYaadRakhna', '#', '#Elections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#Elections2019']
# Hashs --> ['#BJP', '#loksabha', '#AndhraPradesh']
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019', '#APAssemblyElections2019']
# Hashs --> ['#ElectionsWithHT']
# None
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#MegaFans', '#PSPK', '#PawanKalyan', '#JanasenaParty']
# Hashs --> ['#Elections2019', '#ElectionResul']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionResul']
# Hashs --> ['#Elections2019', '#ElectionResul']
# None
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#Elec']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#LokSabhaElections2019', '#PhirEkBaarModiSarkar', '#Elections2019']
# None
# None
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#LokSabhaElections2019', '#ElectionsWithH']
# Hashs --> ['#56', '#maths', '#Elections2019']
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#LokSabhaElections2019', '#ElectionsWithH']
# Hashs --> ['#Elections2019']
# Hashs --> ['#VijaySankalpYatra', '#Elections2019']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#Elections2019']
# None
# None
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019', '#Dalit']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionResul']
# Hashs --> ['#Elections2019', '#ElectionResul']
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#NOTA2019', '#ElectionWar2019', '#ElectionCommission', '#Elections2019', '#ElectionsWithNDTV', '#ElectionCommision']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#Ramadan', '#Elections2019', '#Muslims']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#LokSabhaElections2019']
# None
# Hashs --> ['#Reservation']
# None
# None
# None
# Hashs --> ['#DemonetisationYaadRakhna', '#PhirEkBaarModiSarkar', '#Elections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#ModiMattome', '#Elections2019', '#Continue', '#']
# Hashs --> ['#Ali', '#YSRCP', '#Elections2019', '#AndhraPradeshElections', '#An']
# Hashs --> ['#56', '#maths', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#BJP']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Ramadan', '#Elections2019', '#Muslims']
# Hashs --> ['#Modi', '#AbhinandanMyHero', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#jaideshparty', '#jaideshandhra', '#jaideshtelangana', '#jaideshtelanganasupportmp', '#jaideshandhrasupportmlamp', '#Andhra']
# Hashs --> ['#Elections2019', '#ElectionResul']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Countdown', '#HumanRights', '#10DaysToGo']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#PhirEkBaarModiSarkar']
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#600CroreVoter', '#564Seats', '#ABPnews']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OTV', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# Hashs --> ['#LokSabhaElections2019']
# None
# Hashs --> ['#ElectionsWithMC', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#ElectionCampaign', '#ElectionManagement', '#PR', '#ManagementOfElection', '#ElectionCampaigning', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Demonetisation', '#Elections2019']
# None
# None
# None
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#LokSabhaElections2019', '#Elections']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Demonetisation', '#Elections2019']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#MCopinion', '#elections2019']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Elections2019', '#KanoDecides2019', '#Kano']
# None
# None
# None
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#YSJaganForCM', '#Elections2019']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#BJP', '#UttarPradesh', '#YogiAdityanath']
# Hashs --> ['#OneNation_OneElection', '#OppositionParties']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#JaiHind', '#Elections2019', '#ElectionWar2019']
# Hashs --> ['#stains', '#Vote', '#BetterIndia', '#LokSabhaElections2019', '#Elections2019', '#VanchitBahujan']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#ElectionWar2019', '#MeraBoothSabseMazboot', '#Elections2019']
# Hashs --> ['#Pakistan', '#Nuclear', '#India']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#Elections2019']
# None
# None
# Hashs --> ['#Dalalmedia', '#ShutDownDalalMedia', '#El']
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#Demonetisation']
# None
# Hashs --> ['#Elections2019', '#BJP4India', '#Congress']
# None
# Hashs --> ['#Elections2019', '#Muslim', '#Ramzan']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#Elections2019']
# Hashs --> ['#DemonetisationYaadRakhna', '#', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#SoniaGandhi', '#Congress']
# None
# Hashs --> ['#MarketAtClose']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionCommission']
# Hashs --> ['#DemonetisationYaadRakhna', '#', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#elections', '#Ramadan', '#AsaduddinOwaisi', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# None
# None
# None
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#Elections2019']
# None
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#ElectionCommission', '#Maharashtra', '#Elections2019']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#Ramzan']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Preston']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019']
# None
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#ElectionCommission', '#LokSabhaElections2019', '#El']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# None
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# None
# None
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# None
# Hashs --> ['#RavaliJaganKavaliJaga']
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#Elections2019', '#VoteForFan']
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# None
# Hashs --> ['#EC', '#Elections2019', '#OROP', '#NFU2fauj', '#AFdegraded', '#7CPC', '#Minim']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# None
# None
# Hashs --> ['#Democracy']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#ElectionCommissionOfIndia', '#LokSabhaElections2019', '#E']
# Hashs --> ['#Maharashtra', '#WestBengal']
# Hashs --> ['#Elections2019', '#pappu420']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#LS2019', '#Elections2019']
# Hashs --> ['#2019LokSabhaElections', '#Election', '#Democracy', '#LokSabhaElections2019']
# None
# Hashs --> ['#vote', '#SouthAfrica']
# Hashs --> ['#ElectionCommission', '#LokSabhaElections2019', '#PhirEkBaarModiSarkar', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#elections2019']
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#LS2019', '#Elections2019']
# Hashs --> ['#NewsAlert']
# Hashs --> ['#Eleiss', '#ITforBusiness', '#Surat', '#Elections2019', '#ElectionFever']
# Hashs --> ['#Ali', '#YSRCP', '#Elections2019', '#AndhraPradeshElections', '#An']
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# None
# Hashs --> ['#ElectionsWithMC', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#viral', '#SocialMedia', '#ElectionCommission', '#Election2019']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019', '#kisanvirodhimodi']
# Hashs --> ['#Elections2019', '#SAElections2019']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#EC', '#Elections2019', '#OROP', '#NFU2fauj', '#AFdegraded', '#7CPC', '#Minim']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# Hashs --> ['#PhirEkBaarModiSarkar', '#ModiMattome', '#Elections2019', '#Continue', '#']
# Hashs --> ['#CongressPakistanUnited', '#Ele']
# Hashs --> ['#EC', '#Elections2019', '#OROP', '#NFU2fauj', '#AFdegraded', '#7CPC', '#Minim']
# Hashs --> ['#EC', '#Elections2019', '#OROP', '#NFU2fauj', '#AFdegraded', '#7CPC', '#Minim']
# Hashs --> ['#Elections2019']
# Hashs --> ['#LokSabhaElections2019', '#ElectionCommission']
# None
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#Elections2019', '#']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#Elections2019', '#Ramadan']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# Hashs --> ['#ElectionsWithHT']
# None
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#2020', '#Elections2019']
# Hashs --> ['#Ali', '#YSRCP', '#Elections2019', '#AndhraPradeshElections', '#An']
# Hashs --> ['#ElectionCommission']
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# None
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#Elections2019']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#ElectionWar2019', '#MeraBoothSabseMazboot', '#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#ElectionsWithHT']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#23Ma']
# None
# Hashs --> ['#23', '#ModiVsPakistan', '#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#Elections2019', '#RaGa']
# None
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# Hashs --> ['#Elections2019', '#VoteForGlass']
# None
# Hashs --> ['#PadmaShri', '#PadmaBhushan', '#LokSabhaElections2']
# Hashs --> ['#data', '#socialmedia', '#Elections2019']
# Hashs --> ['#Ali', '#YSRCP', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Patanjali']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#ElectionCommission', '#LokSabhaElections2019', '#El']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# Hashs --> ['#INEC', '#ElectionDay', '#LagosDecides2019', '#Elec']
# Hashs --> ['#DemonetisationYaadRakhna', '#', '#Elections2019']
# None
# Hashs --> ['#DemonetisationYaadRakhna', '#Elections2019', '#PhirEKBaarModiSarkaar']
# Hashs --> ['#MyReport', '#Elections2019']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# None
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#INDIA', '#Elections2019', '#ElectionCommission']
# None
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#ElectionCommission', '#LoksabhaElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#ElectionCommission', '#Indiaelection2019']
# None
# None
# Hashs --> ['#Elections2019', '#Ramzan', '#Muslims', '#Sehri']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#AAC', '#AishaBuhari', '#APC', '#Crime', '#ECOWAS', '#ElRufai', '#Elections2019', '#Entertainm']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#NewsAlert']
# Hashs --> ['#Elections2019', '#APElections']
# None
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#E']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#auspol', '#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#PawanKalyan', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#PawanKalyan', '#JanasenaParty']
# Hashs --> ['#Elections2019', '#VoteForGlass']
# None
# Hashs --> ['#Elections2019', '#AP']
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#Muslims', '#Ramzan', '#Voting']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019', '#APAssemblyElections2019']
# Hashs --> ['#Elections2019', '#Misandry', '#MenVoteBank']
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# None
# Hashs --> ['#maths', '#Elections2019', '#NaMoAgain']
# Hashs --> ['#Muslims', '#Ramzan', '#Voting']
# Hashs --> ['#Reflections', '#Elections2019', '#Democracy', '#voters']
# None
# Hashs --> ['#maths', '#Elections2019']
# None
# Hashs --> ['#LokSabhaElections2019', '#Ele']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionsWithSS']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#Dalit']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#DataChorCBN', '#Elections2019']
# None
# Hashs --> ['#Elections2019', '#LokSabhaElections2019']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#LokSabhaElections2019']
# None
# Hashs --> ['#maths', '#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# None
# None
# Hashs --> ['#Elections2019', '#Misandry', '#MenVoteBank']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#APAssemblyElections2019']
# Hashs --> ['#stains', '#Vote', '#BetterIndia', '#LokSabhaElections2019', '#Elections2019', '#VanchitBahujan']
# None
# Hashs --> ['#democracy', '#polls', '#voters']
# None
# None
# Hashs --> ['#JANASENARevolution2019', '#Elections2019', '#VoteForGlass']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#LokSabhaElections2019']
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# None
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# None
# None
# Hashs --> ['#D']
# None
# None
# None
# None
# Hashs --> ['#Thread', '#LokSabhaElections2019', '#Elections2019']
# None
# None
# None
# Hashs --> ['#LokSabhaElections2019', '#SurfExcel', '#Elections2019', '#ModiSeNaHoPayega', '#BJPfails', '#Demonetisat']
# None
# Hashs --> ['#LongEaton', '#Erewash']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# None
# None
# Hashs --> ['#PadmaShri', '#PadmaBhushan']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#DMK', '#TamilNadu']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Kanodecide2019']
# None
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#ModiOnceAgain', '#El']
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#ModiOnceAgain', '#El']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#SharadPawar', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#TRS', '#KTR', '#KTRTRS', '#Komatireddy', '#Congress']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Election', '#Ramadan']
# None
# None
# Hashs --> ['#NewsAlert']
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#abhinandan', '#Modi2019Wave', '#Elections2']
# None
# None
# Hashs --> ['#stains', '#Vote', '#BetterIndia', '#LokSabhaElections2019', '#Elections2019', '#VanchitBahujan']
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#LagosDecides']
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#NamoAgain', '#Elections2019']
# None
# Hashs --> ['#GuineaBissau']
# None
# None
# Hashs --> ['#Elections2019', '#voteWisely']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elec']
# None
# None
# None
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# None
# Hashs --> ['#DemonetisationYaadRakhna']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#VoteForGlass']
# Hashs --> ['#Elections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# Hashs --> ['#Elections2019', '#VoteForGlass']
# Hashs --> ['#Ramadan', '#LokSabhaElections2019', '#LoksabhaElection', '#Elections2019']
# Hashs --> ['#LoksabhaElections', '#Karnataka', '#Elections2019', '#al']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# Hashs --> ['#ekbaarphirmodisarkaar', '#modi2019', '#elections2019', '#bjp']
# Hashs --> ['#Cricketers', '#ArmedForces']
# Hashs --> ['#RangLaayeSang']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#Elections2019', '#CasteYourVote']
# None
# None
# Hashs --> ['#Nehru']
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#Elections2019', '#MeraBoothSabseMazboot', '#ElectionCommi']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#EkBarFirModiSarkar', '#ElectionCommission', '#CongressMuktBharat', '#Elections2019']
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#Elections2019', '#ANC', '#DA', '#EFF', '#voters', '#CyrilRamaphosa']
# Hashs --> ['#speakout', '#Elections2019']
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#AIMIM', '#']
# Hashs --> ['#Elections2019', '#APAssemblyElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019']
# None
# None
# Hashs --> ['#Elections2019', '#daggaparty', '#dagga', '#Politics', '#polticialparties']
# None
# None
# Hashs --> ['#ElectionCommission', '#LokSabhaElection2019', '#Elections2019', '#TNNaMoWa']
# Hashs --> ['#ElectionsWithSS']
# None
# None
# None
# Hashs --> ['#ElectionsWithHT']
# None
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Murus', '#KadunaDecides2019', '#Elections2019', '#KadunaDecides']
# None
# None
# None
# Hashs --> ['#stains', '#Vote', '#BetterIndia', '#LokSabhaElections2019', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#LokSabhaElection2019', '#Elections2019', '#TNNaMoWa']
# None
# Hashs --> ['#Elections2019', '#VoterID', '#Vote']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#IFP', '#Elections2019', '#impressed', '#KZN']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#ANC']
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#NigeriaDecides2019', '#AkwaIbomDecides', '#Elections2019']
# Hashs --> ['#ANC']
# None
# Hashs --> ['#ElectionCommission', '#LokSabhaElection2019', '#Elections2019', '#TNNaMoWa']
# Hashs --> ['#Elections2019']
# Hashs --> ['#LokSabhaElections2019', '#SurfExcel', '#Elections2019', '#ModiSeNaHoPayega', '#BJPfails']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#Telangana', '#AIMIM', '#AsadOawisi', '#Hyderabad']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Democracy', '#Elections2019']
# Hashs --> ['#EkBarFirModiSarkar', '#ElectionCommission', '#CongressMuktBharat', '#Elections2019']
# Hashs --> ['#BabuBajrangi', '#LokSabhaElections2019', '#Elections2019']
# None
# None
# Hashs --> ['#Elec']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#EkBarFirModiSarkar', '#ElectionCommission', '#CongressMuktBharat', '#Elections2019']
# Hashs --> ['#Elections2019', '#socialmedia', '#monito']
# Hashs --> ['#NewsAlert']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionCommission']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Nigeri']
# Hashs --> ['#NationalSecurity', '#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#JANASENARevolution2019', '#Elections2019', '#VoteForGlass']
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# Hashs --> ['#Elections2019', '#Ramzan', '#MondayMotivation']
# Hashs --> ['#secularism', '#seculariam', '#AchchheDin']
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#NationalSecurity', '#Elections2019']
# None
# Hashs --> ['#Elec']
# Hashs --> ['#ElectionsWithMC', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019', '#VoterID', '#Vote']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#LokSabhaElection2019', '#Elections2019', '#TNNaMoWa']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Demonetisation', '#Elections2019']
# None
# Hashs --> ['#Sikkim', '#SDF']
# None
# None
# Hashs --> ['#Elections2019', '#Tamilnadu']
# None
# Hashs --> ['#Elections2019', '#voteWisely']
# Hashs --> ['#TrappistInfotech']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019', '#elections', '#GeneralElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019', '#ElectionCommission', '#LokSabhaElections2019', '#APelections2019', '#ElectionCommissionOfIndia']
# None
# Hashs --> ['#BabuBajrangi', '#LokSabhaElections2019', '#Elections2019']
# Hashs --> ['#Countdown', '#HumanRights', '#10DaysToGo']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#', '#Like', '#Reply', '#ElectionCommission', '#Election2019']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#LokSabhaElections2019', '#Elections2019', '#Election2019', '#ElectionCommissionOfIndia']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# None
# Hashs --> ['#NigeriaDecides2019', '#AkwaIbomDecides', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Israel', '#Elections2019', '#USAID']
# Hashs --> ['#Demonetisation', '#Elections2019']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#ModiMattome', '#Elections2019', '#Continue', '#']
# Hashs --> ['#Elections2019', '#Continue', '#TransformingIndia']
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#Elec']
# None
# Hashs --> ['#Balayya', '#Hindupur', '#HindupurMLA', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#Demonetisation', '#Elections2019']
# Hashs --> ['#apnatimeaagaya', '#AbkiBaarPhirModiSarkar', '#PhirEkBaarModiSarkar']
# None
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#E']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# Hashs --> ['#Elections2019', '#ElectionCommission', '#Indiaelection2019']
# Hashs --> ['#elections2019']
# Hashs --> ['#M']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#MyVoteForModi']
# Hashs --> ['#LokSabha', '#Parli']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#Modibhakt']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Sensex', '#Nifty']
# None
# Hashs --> ['#Elections2019', '#Misandry', '#MenVoteBank']
# None
# None
# Hashs --> ['#Elec']
# Hashs --> ['#Elections2019', '#PhirEkBaarModiSarkar']
# Hashs --> ['#LokSabhaElections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#ElectionCommission', '#LokSabhaElections2019', '#El']
# Hashs --> ['#Elections2019', '#mine', '#YSRCP', '#jai_jagan_anna']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# None
# None
# None
# Hashs --> ['#SundayThoughts']
# None
# Hashs --> ['#Hitler', '#E']
# Hashs --> ['#PhirEkBaarModiSarkar', '#ModiMattome', '#Elections2019', '#Continue', '#']
# Hashs --> ['#PhirEkBaarModiSarkar', '#ElectionCommission', '#LokSabhaElections2019', '#El']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Muslims', '#Boycott', '#Elections2019']
# Hashs --> ['#Elections2019', '#Balakot']
# Hashs --> ['#EC']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019']
# None
# Hashs --> ['#PhirEkBaarModiSarkar', '#ElectionCommission', '#LokSabhaElections2019', '#El']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Gandhi', '#Elections2019']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#NOTA2019', '#ElectionWar2019', '#ElectionCommission', '#Elections2019', '#ElectionsWithNDTV', '#ElectionCommision']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# None
# None
# None
# Hashs --> ['#Muslims', '#Vote', '#Elections2019']
# Hashs --> ['#PhirEkBaarModiSarkar', '#ElectionCommission', '#LokSabhaElections2019', '#El']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#E']
# None
# None
# Hashs --> ['#TMC']
# Hashs --> ['#Elections2019', '#elections', '#GeneralElections2019']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#Elections2019', '#Polls']
# None
# Hashs --> ['#TimesMegaPoll', '#Elections2019', '#PhirEkBaarMo']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#NewsAlert']
# Hashs --> ['#ModiSeNaHoPayega', '#Elections2019']
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#auspol', '#Elec']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionInMyArea2019']
# None
# Hashs --> ['#BabuBajrangi', '#LokSabhaElections2019', '#Elections2019']
# Hashs --> ['#Von2019elections', '#Nigeriadecide2019', '#Ni']
# Hashs --> ['#India', '#indian']
# Hashs --> ['#NOTA2019', '#ElectionWar2019', '#ElectionCommission', '#Elections2019', '#ElectionsWithNDTV', '#ElectionCommision']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019', '#VijayTilak', '#ModiOnceMore', '#']
# Hashs --> ['#Countdown', '#HumanRights', '#10DaysToGo']
# Hashs --> ['#Sensex', '#DalalStreet']
# Hashs --> ['#ElectionsWithHT', '#LokSabhaElections2019', '#E']
# None
# None
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#Elections2019', '#PhirEkBaarM']
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# None
# Hashs --> ['#ElectionsWithHT']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Sensex', '#DalalStreet', '#Elections2019']
# Hashs --> ['#Terrorists', '#PULWAMATERRORATTACK']
# Hashs --> ['#PhirEkBaarModiSarkar', '#Elections2019', '#LokSabhaElection2019', '#ModiVsPakis']
# Hashs --> ['#PhirEkBaarModiSarkar', '#ModiMattome', '#Elections2019', '#Continue', '#']
# Hashs --> ['#NOTA2019', '#ElectionWar2019', '#ElectionCommission', '#Elections2019', '#ElectionsWithNDTV']
# None
# Hashs --> ['#ElectionCommission', '#LokSabhaElections2019', '#PhirEkBaarModiSarkar', '#Elections2019']
# None
# Hashs --> ['#ElectionCommission', '#Elections']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#Odisha']
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#Elections2019', '#SAElections2019']
# None
# None
# None
# Hashs --> ['#RamzanControversy', '#Ramzan']
# Hashs --> ['#Hyderabad', '#magic', '#india', '#Elections2019']
# None
# Hashs --> ['#ModiOnceAgain', '#El']
# None
# None
# Hashs --> ['#Elections2019', '#PhirEkBaarModiSarkar', '#INDvAUS', '#PadmaShri', '#']
# None
# None
# Hashs --> ['#ElectionCommission', '#Elections2019', '#TrendingNow']
# Hashs --> ['#Countdown', '#HumanRights', '#10DaysToGo']
# None
# None
# Hashs --> ['#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#ElectionCommission', '#LokSabhaElections2019', '#PhirEKBaarModiSarkaar', '#Elections2019', '#Ele']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Countdown', '#HumanRights', '#10DaysToGo']
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# None
# Hashs --> ['#Elections2019', '#SAElections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#JammuKashmir']
# Hashs --> ['#indianelections2019', '#Voting']
# Hashs --> ['#SundayThoughts']
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Pakistan', '#Terrorists', '#Surgicalstrike2', '#IndianAirForce']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#NewsAlert']
# None
# None
# Hashs --> ['#ModiOnceAgain', '#El']
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews', '#']
# Hashs --> ['#Elections2019', '#ElectionsWithGoNews']
# Hashs --> ['#Elections2019']
# Hashs --> ['#NewsAlert', '#Elections2019']
# Hashs --> ['#BhartiyaJumalaParti', '#PracharMantris']
# Hashs --> ['#SocialMedia', '#ElectionCommission', '#Elections2019', '#Election2019', '#Electi']
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#SAElections2019']
# Hashs --> ['#SocialMedia', '#ElectionCommission', '#Elections2019', '#Election2019']
# Hashs --> ['#Chandrababu', '#AndhraPradesh', '#AndhraPradeshElections', '#tdp', '#ysrcp', '#janasena']
# Hashs --> ['#Elections2019', '#SAElections2019']
# Hashs --> ['#Elections2019', '#LokSabhaElections2019']
# None
# None
# None
# Hashs --> ['#DelhiCapitals', '#india', '#raped', '#TamilNadu', '#arrestpollachirapists', '#po']
# None
# Hashs --> ['#Elections2019', '#ElectionCommission']
# None
# Hashs --> ['#Econobabble', '#economy', '#Elections2019', '#auspol']
# Hashs --> ['#Elections2019', '#SAElections2019']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#Election2019', '#Elections2019', '#LokSabhaElections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#Elections']
# None
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#seoclerks', '#freecoupon', '#freelancer', '#fiverrseller', '#Fiverr', '#SEO', '#Di']
# Hashs --> ['#Elections2019', '#L']
# Hashs --> ['#Elections2019', '#Dalit']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# Hashs --> ['#OpinionPoll', '#Elections2019']
# None
# Hashs --> ['#NewsAlert']
# None
# None
# Hashs --> ['#Elections2019', '#SAElections2019']
# None
# Hashs --> ['#2019LokSabhaElections', '#express', '#HaqSeVote']
# None
# ...
# Hashs --> ['#Modi', '#India', '#Elections2019']
# Hashs --> ['#ElectionCommission', '#LokSabhaElections2019']
# Hashs --> ['#TDP', '#NCBN', '#YSRCP', '#Jagan', '#TRS', '#KCR', '#Telangana', '#BJP']
# Hashs --> ['#india', '#Elections2019']
# None
# None
# Hashs --> ['#Elections2019', '#Kolkata', '#Hindutva', '#SaffronTer']
# None
# Hashs --> ['#Elections2019', '#Kolkata', '#Hindutva', '#SaffronTer']
# Hashs --> ['#Elections2019', '#Elections']
# Hashs --> ['#Elections2019', '#Kolkata', '#Hindutva']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Modi', '#India', '#Elections2019']
# None
# None
# Hashs --> ['#GoVerify', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Modi', '#India', '#Elections2019']
# Hashs --> ['#Elections2019', '#Elections']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#Elections']
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019', '#Elections']
# Hashs --> ['#Von2019elections', '#Nigeriadecide2019']
# Hashs --> ['#Elections2019', '#Loksabha2019', '#LokSabhaElections']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Elections2019', '#Loksabha2019', '#LokSabhaElections']
# Hashs --> ['#Elections2019']
# Hashs --> ['#cVIGIL']
# Hashs --> ['#Elections2019']
# Hashs --> ['#']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Von2019elections']
# Hashs --> ['#Odisha', '#women', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Lucknow', '#VaadVivadSamvaad']
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#Von2019elections', '#Nigeriadecide20']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Kandahar', '#Elections2019']
# None
# Hashs --> ['#Von2019elections']
# Hashs --> ['#BettyNwa', '#Elections2019', '#TheVerdict']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#ElectionCommission', '#Elections2019']
# Hashs --> ['#elections2019']
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Modi', '#India', '#Elections2019']
# Hashs --> ['#Otope', '#LagosDecides2019']
# Hashs --> ['#Elections2019', '#Elections']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Modi', '#India']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#SundayMotivation', '#NigeriaDecides', '#N']
# Hashs --> ['#Elections2019', '#Elections']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Elec']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#ElectionCommission']
# Hashs --> ['#Otope', '#LagosDecides2019', '#Otoge', '#OyoDecide2019', '#Elections20']
# Hashs --> ['#Ponda', '#Margao', '#MGP', '#Borim']
# Hashs --> ['#Sunday', '#Elections2019']
# None
# Hashs --> ['#']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#ElectionCommission', '#LokSabhaElections2019']
# Hashs --> ['#electioncommission', '#2019LokSabha', '#Elections2019']
# None
# Hashs --> ['#Balakot', '#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#Su']
# None
# Hashs --> ['#Chowdikar', '#Rafale']
# Hashs --> ['#SundayMotivation', '#NigeriaDecides', '#Elections']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# Hashs --> ['#politics', '#leadership', '#socialmedia']
# Hashs --> ['#ElectionCommission']
# Hashs --> ['#LagosDecides2019', '#LagosDecides', '#MyPVCForSanwoolu', '#Elec']
# None
# Hashs --> ['#PwD', '#Elections2019', '#Ranchi', '#Divyang']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#TDP', '#YSRCP', '#Jagan', '#NCBN', '#ChandrababuNaidu']
# None
# Hashs --> ['#CongressMuktBharat', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Elections2019', '#VijayTilak', '#ModiOnceMore', '#']
# None
# Hashs --> ['#ElectionCommission']
# Hashs --> ['#']
# Hashs --> ['#Elections2019']
# Hashs --> ['#8May']
# Hashs --> ['#Su']
# Hashs --> ['#MSDhoni', '#Mohali', '#4thODI', '#Elections2019', '#Viratkohli']
# Hashs --> ['#']
# Hashs --> ['#ModiOnceMore', '#BJP4India', '#Elections2019']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionCommission']
# Hashs --> ['#LokSabhaElections2019', '#TamilNadu', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#SundayMotivation', '#NigeriaDecides', '#N']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Su']
# Hashs --> ['#Su']
# Hashs --> ['#SundayMotivation', '#NigeriaDecides', '#N']
# Hashs --> ['#Elections2019', '#electioncommission']
# None
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#film', '#AK59', '#MumbaiCollective2019', '#SundayMotivation', '#SundayMorning']
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#BREAKING', '#2019Election', '#Elections2019', '#VerdictOnMo']
# None
# None
# None
# None
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#SundayMotivation', '#NigeriaDecides', '#Elections']
# None
# Hashs --> ['#ec', '#Congress']
# Hashs --> ['#savecutoff90_97']
# Hashs --> ['#SundayMotivation', '#NigeriaDecides']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#SundayMotivation', '#NigeriaDecides', '#N']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#']
# Hashs --> ['#SundayMotivation']
# None
# None
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#']
# Hashs --> ['#NewerAgenda']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#Sunday', '#Elections2019']
# None
# None
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#']
# Hashs --> ['#Elections2019', '#KamalHaasan']
# Hashs --> ['#']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#Otope', '#LagosDecides2019', '#Otoge', '#OyoDecide2019', '#Elections20']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# None
# None
# Hashs --> ['#elections']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#ElectionCommission', '#Elections2019']
# Hashs --> ['#OruViralPuratchi', '#EUelections2019', '#Elections2019', '#Torchlight', '#', '#ADMK', '#DMK']
# None
# None
# None
# Hashs --> ['#MulayamSingh']
# None
# None
# Hashs --> ['#cVIGIL']
# Hashs --> ['#']
# None
# None
# Hashs --> ['#savecutoff90_97']
# None
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# None
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Von2019elections', '#Nigeriadecide2019']
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#aap', '#Congress']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# None
# Hashs --> ['#']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# None
# None
# Hashs --> ['#loksabhaelections2019', '#NewerIndia']
# None
# Hashs --> ['#']
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#elections2019', '#ElectionCommission', '#Election2019', '#LokSabhaElection2019']
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#MumbaiCollective2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#Modi2019Wave', '#RahulGandhi', '#Elections2019', '#LokSabhaEl']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#NorthEast', '#Congress']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# Hashs --> ['#Devegowda', '#Nepotism', '#elections2019']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#savecutoff90_97']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Lucknow', '#VaadVivadSamvaad']
# Hashs --> ['#Elections2019']
# None
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# Hashs --> ['#MulayamSingh']
# None
# Hashs --> ['#elections2019']
# Hashs --> ['#Elections2019', '#Election2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Lucknow', '#VaadVivadSamvaad']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#cVIGIL']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#savecutoff90_97']
# Hashs --> ['#loksabhaelections2019', '#ElectionCommission', '#AAP']
# Hashs --> ['#Chor']
# Hashs --> ['#BREAKING', '#2019Election', '#Elections2019', '#VerdictOnMo']
# None
# None
# Hashs --> ['#MsimangaForPremier', '#voting', '#2019goals', '#blueenergy', '#democrat']
# None
# None
# Hashs --> ['#Sunday', '#Elections2019']
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# None
# None
# None
# None
# Hashs --> ['#']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Elections2014', '#Ele']
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# None
# None
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Sunday', '#Elections2019']
# None
# None
# Hashs --> ['#BatteryTorch', '#MakkalNeedhiMaiam', '#kamalhassan', '#MakkalNeedhiMaiam', '#elections2019']
# Hashs --> ['#ElectionCommission', '#Elections2019']
# Hashs --> ['#elections2019']
# None
# Hashs --> ['#Elections2019', '#VijayTilak']
# None
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#Modi2019Wave', '#RahulGandhi', '#Elections2019', '#LokSabhaEl']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#Elections2019']
# Hashs --> ['#ElectionCommission', '#pollcampaigns']
# None
# Hashs --> ['#Elections2019', '#VoteIndiaAhead']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Elections2019', '#ElectionCommission']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# None
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# None
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# None
# Hashs --> ['#ElectionCommission', '#Elections2019']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Sunday', '#Elections2019']
# None
# Hashs --> ['#Elections2014', '#Ele']
# None
# None
# Hashs --> ['#Sunday', '#Elections2019']
# None
# Hashs --> ['#INEC', '#ElectionDay', '#LagosDecides2019', '#Elec']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#INEC', '#ElectionDay', '#LagosDecides2019', '#Elec']
# None
# None
# Hashs --> ['#Elections2014']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Elections2019']
# Hashs --> ['#SundayMotivation', '#', '#Sundaythoughts']
# Hashs --> ['#india', '#Elections2019', '#elections']
# Hashs --> ['#von2019elections', '#Nigeriadecides2019', '#Nigeriavot']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Odisha', '#women', '#Parliament', '#elections2019', '#Biju']
# Hashs --> ['#Odisha', '#women', '#Parliament']
# None
# Hashs --> ['#kerala', '#Elections2019']
# Hashs --> ['#Loksabha2019', '#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# Hashs --> ['#von2019elections']
# Hashs --> ['#Ethiopia', '#Parliament']
# Hashs --> ['#ElectionCommission', '#Elections2019']
# None
# Hashs --> ['#OruViralPuratchi', '#EUelections2019', '#Elections2019', '#Torchlight', '#', '#ADMK', '#DMK']
# Hashs --> ['#Rahulgandhi', '#Elections2019', '#ElectionCommission', '#BREAKING', '#SundayMotivation']
# Hashs --> ['#Sunday', '#Elections2019']
# Hashs --> ['#Odisha', '#women', '#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#von2019elections', '#Nigeriadecides2019']
# Hashs --> ['#Sundowns', '#BeyondZeroCorruption']
# Hashs --> ['#ElectionCommissionOfIndia', '#Elections2019', '#ElectionCommission']
# Hashs --> ['#Elections2019', '#VoteIndiaAhead']
# None
# None
# None
# None
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# Hashs --> ['#AAC', '#']
# None
# Hashs --> ['#elections2019']
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#SundayThoughts']
# None
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#NigeriaDecides2019', '#ElectionNotWar']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019', '#ElectionCommission']
# Hashs --> ['#Elect']
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# None
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# None
# None
# None
# Hashs --> ['#SundayThoughts']
# None
# None
# None
# None
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#Elections2019']
# Hashs --> ['#nigeriadecide2019', '#Elections2019']
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Kerala', '#Thiruvananthapuram']
# Hashs --> ['#Elections2019']
# Hashs --> ['#Elections2019']
# None
# Hashs --> ['#WhatIDoIDo', '#WhatIDo']
# None
# None
# None
# None
# None
# None
# None
# Hashs --> ['#SundayThoughts']
# Hashs --> ['#SundayThoughts']
# None
# Hashs --> ['#WhatIDoIDo', '#WhatIDo']
# None
# Hashs --> ['#Elec']
# None
# Hashs --> ['#Elections2019', '#GuberElection', '#Nigeriadecides']
# None
# None
# None
# Hashs --> ['#ElectionCommission']
# None
# Hashs --> ['#Elections2019']
# None
# None
# None
# None
# None
# None
# Hashs --> ['#SundayThoughts']
# None
# None
# None
# None
# Hashs --> ['#SundayThoughts']
# None
# Hashs --> ['#SundayThoughts']
# None
# None
# Hashs --> ['#']
# Hashs --> ['#']

# %%
df.head()
# Out:
#                                                Tweet        Date      time  \
# 0   @arpitajtweets: Just for fun\xf0\x9f\x91\x8d\...  2019-03-10  07:52:48
# 1  Where is safety,how we safe,this is the situat...  2019-03-10  07:52:48
# 2   @ManiDevaMS: #DelhiCapitals is not only #indi...  2019-03-10  07:52:48
# 3   @VinayDokania: How Indian Journalists come ou...  2019-03-10  07:52:48
# 4  #Elections2019 Dates are finally out. @BoredBr...  2019-03-10  07:52:48
#
#   Tweet_type                                          hash_tags
# 0         RT                 [#MondayMotivaton, #Elections2019]
# 1          T      [#India, #ElectionCommission, #Elections2019]
# 2         RT  [#DelhiCapitals, #india, #raped, #TamilNadu, #...
# 3         RT                     [#OpinionPoll, #Elections2019]
# 4          T                                   [#Elections2019]

# %%
#Seperating the Usertags from the Tweets
df['user_tags'] = "NA"
for i in range(0,len(df['Tweet'])):
    result = re.findall('@[\w]*',df['Tweet'][i])
    if result:
        print( "Tags --> %s " % result)
        df['user_tags'][i] = result
    else:
        print("None")
        df['user_tags'][i] = "None"
# Out:
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# None
# Tags --> ['@ManiDevaMS']
# Tags --> ['@VinayDokania']
# Tags --> ['@BoredBroacha']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@sunetrac']
# Tags --> ['@streetbilionare']
# Tags --> ['@VinayDokania']
# Tags --> ['@moneycontrolcom', '@ArunJaitley', '@BJP']
# Tags --> ['@OfficialAPCNg']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@prashanho', '@narendramodi', '@BJP4India', '@AmitShah']
# Tags --> ['@streetbilionare']
# None
# Tags --> ['@MahimaShastri']
# Tags --> ['@imMAQ_7']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@BoredBroacha']
# Tags --> ['@htTweets']
# Tags --> ['@RavinarIN', '@KhanAmanatullah']
# Tags --> ['@BurnolReloaded', '@narendramodi']
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# None
# Tags --> ['@RahulGandhi']
# Tags --> ['@MobilePunch']
# Tags --> ['@saviour_era', '@loksabhatv']
# Tags --> ['@VinayDokania']
# Tags --> ['@uniksoundsng']
# None
# Tags --> ['@htTweets']
# Tags --> ['@otvnews']
# Tags --> ['@INCIndia', '@AamAadmiParty']
# Tags --> ['@abhaysi95810486']
# Tags --> ['@NishantJaiHind']
# None
# None
# Tags --> ['@rajeev_mp']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@vaishnavi_1001', '@Dev_Fadnavis']
# None
# Tags --> ['@KumariRukshmani']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@SatyaNamo']
# None
# Tags --> ['@RamMNK']
# None
# Tags --> ['@LoveLes_7']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@VollCornHirsch']
# Tags --> ['@frittzeegirl']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@uniksoundsng']
# Tags --> ['@madamevecartoon']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@sanjoy_takam']
# Tags --> ['@Dev_Fadnavis']
# Tags --> ['@sanjoy_takam']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@Neeraj_2019']
# Tags --> ['@VinayDokania']
# Tags --> ['@Proactivesms']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@LogicalIndians']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@VinayDokania']
# Tags --> ['@rajeev_mp']
# Tags --> ['@ArunJaitley']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Kasheer_suneel']
# None
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# None
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@vibhamathur10']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@narendramodi', '@MehboobaMufti', '@OmarAbdullah']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# Tags --> ['@SINGHRAJIVRANA1']
# Tags --> ['@sudarsansand']
# Tags --> ['@RamMNK']
# Tags --> ['@HCookey']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@MosagaduBabu', '@ysjagan', '@ncbn']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@ANI']
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# None
# Tags --> ['@CongressSevadal']
# Tags --> ['@VinayDokania']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@WIONews']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@CEOAndhra']
# Tags --> ['@RadhikaBarman5']
# None
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# Tags --> ['@bakarabdull']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@VinayDokania']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@vibhamathur10']
# None
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# None
# Tags --> ['@kiranychandra']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@abhaysi95810486']
# Tags --> ['@VinayDokania']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@MOP_OFFICIAL']
# Tags --> ['@TrendPSPK', '@PawanKalyan']
# Tags --> ['@MahimaShastri']
# None
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@HCookey']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@anuraagmuskaan']
# Tags --> ['@sunilkapoor8', '@sunilkapoor8', '@Twitter', '@jack', '@BJP4India', '@Ra_THORe', '@Swamy39', '@jeetensingh', '@PuriViren']
# Tags --> ['@pallabghosh']
# Tags --> ['@Policyprocesses']
# Tags --> ['@SatyaNamo']
# None
# None
# Tags --> ['@RamMNK', '@ysjagan']
# None
# None
# Tags --> ['@arpitajtweets', '@narendramodi', '@BJP4India']
# Tags --> ['@ATMovement_SA']
# Tags --> ['@HCookey']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@abhaysi95810486']
# Tags --> ['@NatarajanBalan', '@BJP4India', '@narendramodi']
# Tags --> ['@WazobiaOnitsha', '@GIGZEBUKA', '@cyprex_fanss', '@ZoRoSwaGBaG']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@s_anuj']
# Tags --> ['@imanojprabakar']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@news18dotcom', '@asadowaisi']
# Tags --> ['@TrendPSPK', '@PawanKalyan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@siddaramaiah']
# Tags --> ['@VinayDokania']
# Tags --> ['@LiveLawIndia']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@TrendPSPK', '@PawanKalyan']
# Tags --> ['@SaharaReporters', '@Offici']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# None
# Tags --> ['@ManiDevaMS']
# Tags --> ['@news18dotcom']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@VinayDokania']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@VinayDokania']
# Tags --> ['@saviour_era', '@loksabhatv']
# Tags --> ['@SaharaReporters']
# None
# Tags --> ['@srivatsayb']
# Tags --> ['@narendramodi']
# Tags --> ['@bakarabdull']
# Tags --> ['@SAMsHowitzer']
# Tags --> ['@JanaSenaParty', '@PawanKalyan']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@news18dotcom']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@MahimaShastri']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@nirajcyber27']
# Tags --> ['@CongressSevadal']
# Tags --> ['@narendramodi', '@Twitter', '@facebook']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@HerrBains']
# Tags --> ['@CTRavi_BJP']
# None
# None
# Tags --> ['@indrajithIn', '@PawanKalyan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@siddaramaiah', '@BSYBJP', '@hd_kumaraswamy']
# Tags --> ['@jagdishshetty', '@JhaSanjay']
# Tags --> ['@pavanmirror']
# Tags --> ['@htTweets']
# Tags --> ['@threadreaderapp', '@NindiPunj', '@Kasheer_suneel', '@n']
# Tags --> ['@narendramodi', '@BJP4India']
# Tags --> ['@Neeraj_2019']
# Tags --> ['@DrMonmohanSingh']
# Tags --> ['@CongressSevadal']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@inecnigeria']
# Tags --> ['@VinayDokania']
# Tags --> ['@KasapoguPrakash']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@VinayDokania']
# None
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@narendramodi']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@_Fury_at_times', '@PawanKalyan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@otvnews']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@sttalkindia']
# Tags --> ['@imfarzkhan']
# Tags --> ['@rayonkiran29']
# Tags --> ['@Neeraj_2019']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@srivatsayb']
# Tags --> ['@chgzamalu4']
# Tags --> ['@bakarabdull']
# Tags --> ['@ceo_karnataka']
# Tags --> ['@imfarzkhan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@htTweets']
# Tags --> ['@VinayDokania']
# Tags --> ['@DeoKalikesh', '@stc_india']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@CongressSevadal']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@firinneireland', '@TwiterusMaximus']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@igtelugu']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@prosperotree']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@ANI', '@PawarSpeaks']
# Tags --> ['@abarTMC']
# None
# Tags --> ['@frankdonga_']
# Tags --> ['@bakarabdull']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@chgzamalu4']
# Tags --> ['@chgzamalu4']
# Tags --> ['@HCookey']
# Tags --> ['@VinayDokania']
# Tags --> ['@INCIndia', '@ArvindKejriwal']
# Tags --> ['@htTweets', '@narendramodi']
# Tags --> ['@htTweets']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@shefali_bagga']
# Tags --> ['@JatothuH', '@narendramodi']
# Tags --> ['@seemaadhikari']
# Tags --> ['@facebook', '@WhatsApp']
# Tags --> ['@digitaldutta']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@htTweets']
# None
# Tags --> ['@htTweets', '@sanjoy_dey25']
# Tags --> ['@VinayDokania']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@htTweets']
# Tags --> ['@amin_owaisi']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@VishweshwarBhat']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@VinayDokania']
# Tags --> ['@igtelugu']
# Tags --> ['@Kasheer_suneel']
# Tags --> ['@sudarsansand']
# Tags --> ['@thesickular']
# Tags --> ['@htTweets', '@sanjoy_dey25']
# None
# None
# None
# Tags --> ['@syedibrahim967']
# None
# None
# Tags --> ['@HCookey']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@TwiterusMaximus']
# None
# Tags --> ['@aajtak', '@PankajJainClick', '@AamAadmiParty', '@SanjayAzadSln']
# Tags --> ['@siddaramaiah']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@meinardus']
# Tags --> ['@nidhilall', '@ArvindKejriwal', '@mlkhattar', '@PMOIndia', '@nitin_gadkari']
# Tags --> ['@TarunRajSingh_', '@RahulGandhi', '@MajorPoonia']
# Tags --> ['@Cybermum_India']
# None
# None
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@HazaribagSveep']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Who_Kajal']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@HazaribagSveep']
# Tags --> ['@SarojDassi1', '@SaintRampalJiM']
# Tags --> ['@Rita_Banerji']
# Tags --> ['@pavanmirror']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@drabhishekjain', '@DXPAssociation', '@SushmaSwaraj', '@nitin_gadkari', '@arunjaitley', '@ArvindKejriwal', '@SatyendarJain', '@mlkhattar', '@Rao_InderjitS', '@Rao']
# None
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Kkdtalkies']
# Tags --> ['@htTweets']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# None
# Tags --> ['@chgzamalu4']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@BabuSaheb90']
# Tags --> ['@chgzamalu4']
# Tags --> ['@chgzamalu4']
# Tags --> ['@PresidentVerde']
# Tags --> ['@abhaysi95810486']
# Tags --> ['@htTweets', '@narendramodi']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@NehruKiGalti_']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@pallabghosh']
# Tags --> ['@htTweets']
# Tags --> ['@htTweets']
# Tags --> ['@republic']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@htTweets']
# Tags --> ['@VeereshMalik']
# Tags --> ['@otvnews']
# Tags --> ['@htTweets']
# Tags --> ['@RaghuramanMenon']
# Tags --> ['@KhushiKadri']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@siddaramaiah']
# Tags --> ['@sudarsansand']
# Tags --> ['@SudhinBhadoria']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@chgzamalu4']
# Tags --> ['@chgzamalu4']
# None
# Tags --> ['@abhaysi95810486']
# Tags --> ['@saviour_era', '@loksabhatv']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@faishal_saifi']
# Tags --> ['@VinayDokania']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# None
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@siddaramaiah']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@PresidentVerde']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@rajeev_mp']
# Tags --> ['@igtelugu']
# None
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@IAF_MCC']
# Tags --> ['@VinayDokania']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@chgzamalu4']
# Tags --> ['@sudarsansand']
# Tags --> ['@ThumaFoundation']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# None
# Tags --> ['@JSP_YuvaSena']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@prettypadmaja']
# None
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@VinayDokania']
# Tags --> ['@puneetgarg108']
# Tags --> ['@rahulkpopat']
# None
# Tags --> ['@KapilSibal']
# None
# Tags --> ['@PresidentVerde']
# Tags --> ['@VinayDokania']
# Tags --> ['@alokg2k']
# None
# Tags --> ['@ysjagan', '@ncbn']
# Tags --> ['@VinayDokania']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@prettypadmaja']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@sanju4odisha']
# None
# Tags --> ['@sudarsansand']
# Tags --> ['@htTweets']
# Tags --> ['@sudarsansand']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@kanimozhi']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# None
# Tags --> ['@prettypadmaja']
# Tags --> ['@HCookey']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@siddaramaiah']
# Tags --> ['@VinayDokania']
# Tags --> ['@SaharaReporters', '@OfficialAPCNg']
# Tags --> ['@darshitpandya9']
# Tags --> ['@moneycontrolcom', '@MamataOfficial']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@TarunRajSingh_', '@RahulGandhi', '@MajorPoonia']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@drabhishekjain', '@DXPAssociation', '@SushmaSwaraj', '@nitin_gadkari', '@arunjaitley', '@ArvindKejriwal', '@SatyendarJain', '@mlkhattar', '@Rao_InderjitS', '@Rao']
# Tags --> ['@siddaramaiah']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@sanju4odisha']
# None
# None
# Tags --> ['@sbajpai2806']
# None
# None
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# None
# Tags --> ['@JayBhimSidd']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@abhishekmannu']
# Tags --> ['@BJP4India']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@htTweets']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# None
# Tags --> ['@2Suhana25', '@RubikaLiyaquat']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@sanju4odisha']
# Tags --> ['@TrendPSPK', '@PawanKalyan']
# Tags --> ['@OfficialAPCNg']
# Tags --> ['@SarojDassi1', '@SaintRampalJiM']
# None
# Tags --> ['@iyer_rn', '@as_kapoor', '@advmonikaarora', '@kanimozhi', '@keralaCastro', '@anilindian', '@Kuvalayamala', '@HKupdate', '@girishalva', '@chathootti', '@prafullaketka']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@Outlookindia']
# Tags --> ['@PankajPachauri']
# None
# Tags --> ['@Who_Kajal']
# Tags --> ['@VinayDokania']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@sonalkalra']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@BJP4UP', '@BJP4India', '@Swamy39']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@Who_Kajal']
# Tags --> ['@RamMNK']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@DrSandeepJSP']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@PankajPachauri']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@sonalkalra']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@inecnigeria']
# None
# Tags --> ['@RubeenaJan1']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@takeonedigital']
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@VinayDokania']
# Tags --> ['@prestoncouncil']
# Tags --> ['@abhaysi95810486']
# Tags --> ['@GauPrem']
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# None
# Tags --> ['@RamMNK', '@ysjagan']
# Tags --> ['@cchandramouli1']
# Tags --> ['@rao_nava']
# Tags --> ['@HCookey']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@MahimaShastri']
# Tags --> ['@PankajPachauri']
# Tags --> ['@VinayDokania']
# Tags --> ['@MahimaShastri']
# Tags --> ['@ysjagan']
# Tags --> ['@kollexey']
# Tags --> ['@AadeshRawal', '@Interceptors', '@pankajjha_']
# Tags --> ['@rahulkpopat']
# None
# Tags --> ['@KhushiKadri']
# Tags --> ['@PankajPachauri']
# Tags --> ['@MahimaShastri']
# Tags --> ['@AKYOnline']
# Tags --> ['@narendramodi']
# Tags --> ['@ManviDad']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@HCookey']
# Tags --> ['@VinayDokania']
# Tags --> ['@JSP_YuvaSena']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@Lakshmi02461825']
# Tags --> ['@HCookey']
# Tags --> ['@VinayDokania']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@rahulkpopat']
# Tags --> ['@supriya_sule']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@PankajPachauri']
# Tags --> ['@HazaribagSveep']
# Tags --> ['@varmaopv', '@BJP4India']
# Tags --> ['@frankdonga_']
# Tags --> ['@MahimaShastri']
# Tags --> ['@MahimaShastri']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@htTweets']
# Tags --> ['@CeoManipur']
# None
# Tags --> ['@rahulgandhi']
# Tags --> ['@PankajPachauri']
# Tags --> ['@RediffDataJourn']
# None
# Tags --> ['@MahimaShastri']
# None
# Tags --> ['@NehruKiGalti_']
# Tags --> ['@AtulGuptadsss']
# None
# None
# Tags --> ['@abhaysi95810486']
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@htTweets']
# None
# Tags --> ['@RajnathSingh']
# Tags --> ['@eleissIN']
# Tags --> ['@igtelugu']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@rahulkpopat']
# Tags --> ['@ASTanwar10']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@s_anuj']
# Tags --> ['@narendramodi']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@101reporters']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@SABCNewsOnline']
# Tags --> ['@RamMNK']
# Tags --> ['@sanju4odisha']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@RamMNK']
# Tags --> ['@htTweets']
# Tags --> ['@varmaopv', '@BJP4India']
# Tags --> ['@MahimaShastri']
# Tags --> ['@rahulkpopat']
# Tags --> ['@rajeev_mp']
# Tags --> ['@thesickular']
# Tags --> ['@varmaopv', '@BJP4India']
# Tags --> ['@varmaopv', '@BJP4India']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@moliticsindia']
# Tags --> ['@2much_opoTBdope']
# Tags --> ['@PankajPachauri']
# Tags --> ['@Telugu360']
# None
# Tags --> ['@cchandramouli1']
# Tags --> ['@rayonkiran29', '@narendramodi']
# None
# Tags --> ['@HCookey']
# None
# Tags --> ['@prettypadmaja']
# Tags --> ['@AtulGuptadsss']
# Tags --> ['@htTweets']
# None
# None
# None
# Tags --> ['@igtelugu']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@rahulkpopat']
# Tags --> ['@georgian_mayank']
# None
# Tags --> ['@htTweets']
# Tags --> ['@MandiraKala']
# Tags --> ['@SarojDassi1', '@SaintRampalJiM']
# Tags --> ['@abhishekmannu']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# None
# Tags --> ['@HCookey']
# Tags --> ['@sunetrac']
# Tags --> ['@AAP_ka_yaar']
# Tags --> ['@aftabmrz007']
# None
# Tags --> ['@RavinarIN', '@KhanAmanatullah']
# Tags --> ['@TanushreePande']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@TarunRajSingh_', '@RahulGandhi', '@MajorPoonia']
# Tags --> ['@segalink', '@UKinNigeria', '@USEmbassyAbuja']
# None
# Tags --> ['@Policyprocesses']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@SaintRampalJiM']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@MirchiSayema']
# Tags --> ['@AtulGuptadsss']
# Tags --> ['@PavanOfficiall', '@JanaSenaParty']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@LegalKant']
# Tags --> ['@digitaldutta']
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@VinayDokania']
# Tags --> ['@_NAN_DINI', '@ShivendraKSinh1', '@Hena19']
# Tags --> ['@MahimaShastri']
# Tags --> ['@rao_nava']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@VinayDokania']
# Tags --> ['@rajeev_mp']
# Tags --> ['@KSeriake']
# Tags --> ['@Who_Kajal']
# Tags --> ['@RavinarIN', '@KhanAmanatullah']
# None
# None
# Tags --> ['@sudarsansand']
# Tags --> ['@TarunRajSingh_', '@RahulGandhi', '@MajorPoonia']
# Tags --> ['@sumalathaA', '@BJP4Karnataka', '@BJP4India', '@AmitShah', '@narendramodi']
# Tags --> ['@RaghuramanMenon']
# Tags --> ['@AtulGuptadsss']
# Tags --> ['@AtulGuptadsss']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@AtulGuptadsss']
# Tags --> ['@narendramodi']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@VinayDokania']
# Tags --> ['@abhaysi95810486']
# None
# Tags --> ['@siddaramaiah']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@AtulGuptadsss']
# Tags --> ['@SSMusicTweet']
# Tags --> ['@LBC', '@ianpaynesport']
# None
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@HCookey']
# Tags --> ['@soutikBBC']
# Tags --> ['@MahimaShastri']
# None
# Tags --> ['@Ani0508P']
# Tags --> ['@MrinalPande1']
# None
# Tags --> ['@evidencify']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@NCPspeaks']
# Tags --> ['@V6_Suresh']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@htTweets']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@RavinarIN', '@KhanAmanatullah']
# Tags --> ['@VinayDokania']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@TanushreePande']
# None
# Tags --> ['@sonalkalra']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@WorldPSPKFans']
# Tags --> ['@pythoroshan']
# Tags --> ['@saileshvora55', '@rmburra24', '@SiddharthKS', '@BavejaH', '@u_mirella', '@timelesssoul1', '@Treasure515', '@nitingodbole', '@kkgiyer1969', '@SunitaG1962', '@rpskata']
# Tags --> ['@BurnolReloaded', '@narendramodi']
# None
# Tags --> ['@WorldPSPKFans']
# Tags --> ['@frittzeegirl']
# Tags --> ['@UrsThanuja']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@RahulGandhi']
# Tags --> ['@vshivam_']
# Tags --> ['@menakadoshi']
# Tags --> ['@sonalkalra']
# None
# Tags --> ['@RaghuramanMenon']
# Tags --> ['@pythoroshan']
# Tags --> ['@Kkdtalkies']
# Tags --> ['@its_skp', '@BJP4India']
# None
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@RoadsOfMumbai']
# Tags --> ['@republic']
# None
# Tags --> ['@Prakashukla']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@republic', '@republic']
# None
# Tags --> ['@HTPunjab']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@ThinkChangeIND']
# Tags --> ['@DrSandeepJSP']
# None
# Tags --> ['@SudhinBhadoria']
# Tags --> ['@RahulGandhi']
# Tags --> ['@HCookey']
# Tags --> ['@nidhilall', '@ArvindKejriwal', '@mlkhattar', '@PMOIndia', '@nitin_gadkari']
# Tags --> ['@gandhi_pv', '@pdinakar']
# None
# None
# Tags --> ['@MahimaShastri']
# Tags --> ['@ManiDevaMS']
# None
# Tags --> ['@MahimaShastri']
# Tags --> ['@republic']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# None
# Tags --> ['@its_skp', '@BJP4India']
# Tags --> ['@GoNews24x7', '@PankajPachauri']
# Tags --> ['@Kkdtalkies']
# Tags --> ['@JayBhimSidd']
# Tags --> ['@CongressSevadal']
# None
# Tags --> ['@TanushreePande']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@WorldPSPKFans']
# None
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@SaharaReporters', '@Offici']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@pythoroshan']
# Tags --> ['@PawarSpeaks']
# None
# Tags --> ['@_Fury_at_times', '@PawanKalyan']
# Tags --> ['@SaharaReporters', '@Offici']
# None
# Tags --> ['@sudarsansand']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@DrSandeepJSP']
# Tags --> ['@SaharaReporters', '@Offici']
# Tags --> ['@SaharaReporters']
# Tags --> ['@siddaramaiah']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@siddaramaiah']
# Tags --> ['@siddaramaiah', '@BJP4India']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@siddaramaiah']
# Tags --> ['@Policyprocesses']
# Tags --> ['@HCookey']
# Tags --> ['@meghakaveri']
# Tags --> ['@MahimaShastri']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@Policyprocesses']
# Tags --> ['@bikidullah']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@hiindustanii']
# Tags --> ['@VinayDokania']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@VinayDokania']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@sonalkalra']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@VinayDokania']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@HCookey']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@DrSandeepJSP']
# Tags --> ['@Policyprocesses']
# None
# Tags --> ['@cchandramouli1']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@rajeev_mp']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@sudarsansand']
# Tags --> ['@siddaramaiah']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@siddaramaiah']
# Tags --> ['@sonalkalra']
# None
# Tags --> ['@iankit07', '@narendramodi', '@narendramodi']
# Tags --> ['@AdityaMenon22', '@CvoterIndia']
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@MandiraKala']
# Tags --> ['@iankit07', '@narendramodi', '@narendramodi']
# Tags --> ['@VinayDokania']
# Tags --> ['@oluremisonaiya', '@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@iankit07', '@narendramodi']
# Tags --> ['@HCookey']
# Tags --> ['@inecnigeria', '@HQNigerianArmy']
# Tags --> ['@Policyprocesses']
# None
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# None
# Tags --> ['@sudarsansand']
# None
# None
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@ShayanNasir6']
# Tags --> ['@MahimaShastri']
# Tags --> ['@SaharaReporters', '@Offici']
# Tags --> ['@JayBhimSidd']
# Tags --> ['@HerrBains']
# Tags --> ['@RavinarIN', '@KhanAmanatullah']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@Divya_S_Rathore', '@JhaSanjay']
# Tags --> ['@alokg2k']
# Tags --> ['@GetKwikMoney']
# Tags --> ['@siddaramaiah']
# Tags --> ['@aftabmrz007']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@MandiraKala']
# Tags --> ['@kdhiraj123']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# None
# Tags --> ['@naijadomains']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@KasthuriShankar']
# None
# Tags --> ['@inecnigeria']
# Tags --> ['@VinayDokania']
# Tags --> ['@Ramesh_Dhaka_']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@yogashar99']
# Tags --> ['@PatniGaurav', '@narendramodi']
# Tags --> ['@frittzeegirl']
# Tags --> ['@rajeev_mp']
# Tags --> ['@VinayDokania']
# Tags --> ['@WithDeepakJoshi']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@iankushchoubey', '@GoNews24x7', '@PankajPachauri']
# Tags --> ['@HCookey']
# Tags --> ['@siddaramaiah']
# None
# Tags --> ['@rajeev_mp']
# Tags --> ['@SaharaReporters']
# None
# Tags --> ['@Rita_Banerji']
# Tags --> ['@siddaramaiah']
# Tags --> ['@PavanOfficiall', '@JanaSenaParty']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@PavanOfficiall', '@JanaSenaParty']
# None
# Tags --> ['@ceo_karnataka']
# Tags --> ['@inecnigeria']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@drabhishekjain', '@DXPAssociation', '@cmohry', '@NHAISocialmedia', '@PdGurgaon_NHAI', '@nitin_gadkari', '@vaibhav_74', '@Rao_InderjitS', '@RaoNarbir', '@ramanmal']
# Tags --> ['@kamleshtib']
# Tags --> ['@ashoswai']
# Tags --> ['@DaagAchheHain']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@SpokespersonECI']
# Tags --> ['@SaharaReporters', '@Offici']
# Tags --> ['@ManiDevaMS']
# None
# Tags --> ['@HCookey']
# None
# None
# Tags --> ['@prettypadmaja']
# Tags --> ['@SINGHRAJIVRANA1']
# Tags --> ['@VinayDokania']
# Tags --> ['@bsayyed10']
# Tags --> ['@HazaribagSveep']
# Tags --> ['@cchandramouli1']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@PSBrarOfficial', '@narendramodi', '@PMOI']
# Tags --> ['@HazaribagSveep']
# Tags --> ['@VinayDokania']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@madamevecartoon', '@mailandguardian']
# None
# Tags --> ['@Sahastrabuddhhe', '@BJP4India', '@INCIndia']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@syedibrahim967']
# Tags --> ['@Kkdtalkies']
# Tags --> ['@Rita_Banerji']
# Tags --> ['@sudarsansand']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@darshangor26']
# Tags --> ['@MahimaShastri']
# None
# Tags --> ['@madamevecartoon']
# Tags --> ['@MahimaShastri']
# Tags --> ['@HCookey']
# Tags --> ['@hemaquotes']
# Tags --> ['@ThinkChangeIND']
# Tags --> ['@seenosy']
# Tags --> ['@HCookey']
# None
# Tags --> ['@htTweets']
# Tags --> ['@sanjaypaswanbjp']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@Nohaadams']
# Tags --> ['@MahimaShastri']
# Tags --> ['@KhushiKadri']
# None
# None
# Tags --> ['@hemaquotes']
# Tags --> ['@2much_opoTBdope']
# Tags --> ['@Unis100', '@iamnagarjuna']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@satyajeettambe']
# None
# None
# None
# Tags --> ['@MahimaShastri']
# Tags --> ['@JSP_YuvaSena']
# Tags --> ['@SAbynumbers']
# Tags --> ['@sonalkalra']
# Tags --> ['@PMOIndia', '@narendramodi']
# Tags --> ['@HCookey']
# None
# Tags --> ['@prettypadmaja']
# Tags --> ['@MrAkanOkon', '@MrUdomEmmanuel']
# Tags --> ['@SAbynumbers']
# Tags --> ['@HCookey']
# Tags --> ['@hemaquotes']
# Tags --> ['@Rita_Banerji']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@HCookey']
# Tags --> ['@RadhikaBarman5']
# None
# Tags --> ['@sudarsansand']
# Tags --> ['@RWABhagidari']
# Tags --> ['@bsayyed10']
# Tags --> ['@Awhadspeaks']
# Tags --> ['@MahimaShastri']
# Tags --> ['@Sahastrabuddhhe']
# Tags --> ['@iankushchoubey', '@GoNews24x7', '@PankajPachauri']
# None
# Tags --> ['@Apkal']
# Tags --> ['@bsayyed10']
# Tags --> ['@entrackr']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@VinayDokania']
# Tags --> ['@Sahastrabuddhhe', '@BJP4India', '@INCIndia']
# Tags --> ['@moneycontrolcom']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@KhajuriaManu']
# Tags --> ['@SaharaReporters', '@inecnigeria']
# Tags --> ['@NatarajanBalan', '@BJP4India', '@narendramodi']
# Tags --> ['@PankajPachauri']
# None
# Tags --> ['@TrendPSPK']
# Tags --> ['@Policyprocesses']
# Tags --> ['@amin_owaisi']
# None
# None
# None
# None
# Tags --> ['@rajeev_mp']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@BJP4India', '@narendramodi']
# Tags --> ['@drabhishekjain', '@DXPAssociation', '@SushmaSwaraj', '@nitin_gadkari', '@arunjaitley', '@ArvindKejriwal', '@SatyendarJain', '@mlkhattar', '@Rao_InderjitS', '@Rao']
# Tags --> ['@iankushchoubey', '@GoNews24x7', '@PankajPachauri']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@sudarsansand']
# Tags --> ['@iamnagarjuna']
# None
# Tags --> ['@hemaquotes']
# None
# Tags --> ['@prettypadmaja']
# Tags --> ['@srivatsayb']
# Tags --> ['@PremDasRai']
# Tags --> ['@sanju4odisha']
# Tags --> ['@HCookey']
# None
# Tags --> ['@Policyprocesses']
# Tags --> ['@KasthuriShankar']
# Tags --> ['@trappistinfotec', '@trappistinfotech']
# Tags --> ['@VinayDokania']
# Tags --> ['@sudarsansand']
# Tags --> ['@shefali_bagga']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@sonalkalra']
# Tags --> ['@yakubublogger']
# None
# Tags --> ['@sudarsansand']
# None
# Tags --> ['@siddaramaiah']
# Tags --> ['@Awhadspeaks']
# Tags --> ['@ThumaFoundation']
# Tags --> ['@sudarsansand']
# Tags --> ['@VinayDokania']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# Tags --> ['@TrendPSPK', '@PawanKalyan']
# Tags --> ['@KhabreeLaal']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@sidin']
# None
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@srivatsayb']
# Tags --> ['@HCookey']
# Tags --> ['@MrAkanOkon', '@MrUdomEmmanuel']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@_Fury_at_times', '@PawanKalyan']
# None
# Tags --> ['@prettypadmaja']
# Tags --> ['@HCookey']
# Tags --> ['@rajeev_mp']
# Tags --> ['@rajeev_mp']
# Tags --> ['@News18Politics']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@iankushchoubey', '@GoNews24x7', '@PankajPachauri']
# Tags --> ['@KhajuriaManu']
# Tags --> ['@SUNNY_ROCKZZ9']
# Tags --> ['@sonalkalra']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@prettypadmaja']
# Tags --> ['@puneetgarg108']
# Tags --> ['@Techglares']
# None
# Tags --> ['@prettypadmaja']
# None
# None
# Tags --> ['@srivatsayb']
# Tags --> ['@htTweets']
# Tags --> ['@htTweets', '@subhashpathak']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@soutikBBC']
# Tags --> ['@INCIndia']
# Tags --> ['@DurganshDixit', '@narendramodi', '@narendramodi', '@BJP4India']
# Tags --> ['@htTweets', '@subhashpathak']
# Tags --> ['@sonalkalra']
# Tags --> ['@HCookey']
# Tags --> ['@mrinaljaipur']
# Tags --> ['@AUOYI']
# None
# Tags --> ['@PankajPachauri']
# Tags --> ['@PankajPachauri']
# Tags --> ['@sunilkapoor8', '@Twitter', '@jack', '@BJP4India', '@Ra_THORe', '@Swamy39', '@jeetensingh']
# Tags --> ['@naijadomains']
# Tags --> ['@RamMNK']
# None
# None
# Tags --> ['@its_skp', '@BJP4India']
# None
# None
# Tags --> ['@iankushchoubey', '@GoNews24x7', '@PankajPachauri']
# None
# Tags --> ['@subhashpathak']
# Tags --> ['@VinayDokania']
# Tags --> ['@HerrBains']
# Tags --> ['@rao_nava']
# Tags --> ['@Kiranssmbfan']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@FilmyPramod']
# Tags --> ['@MahimaShastri']
# Tags --> ['@HCookey']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@KhushiKadri']
# Tags --> ['@mujtabachowdary']
# Tags --> ['@rajeev_mp']
# Tags --> ['@rao_nava']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@prashanho', '@narendramodi', '@BJP4India', '@AmitShah']
# Tags --> ['@sonalkalra']
# Tags --> ['@MandiraKala']
# Tags --> ['@IndiaToday', '@Ankit_Tyagi01']
# Tags --> ['@BTVI', '@VinodSharmaView']
# Tags --> ['@sumanthraman']
# Tags --> ['@RamMNK']
# Tags --> ['@georgian_mayank']
# Tags --> ['@prashanho', '@narendramodi', '@BJP4India', '@AmitShah']
# Tags --> ['@mayfair1958']
# Tags --> ['@rao_nava']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@cvisuali']
# Tags --> ['@cchandramouli1']
# Tags --> ['@bhaskarsai']
# Tags --> ['@satyajeettambe']
# Tags --> ['@saviour_era', '@loksabhatv']
# Tags --> ['@sudarsansand']
# Tags --> ['@HCookey']
# Tags --> ['@SrinuIndian1']
# Tags --> ['@MahimaShastri']
# Tags --> ['@CNNnews18', '@abuasimazmi']
# Tags --> ['@rao_nava']
# Tags --> ['@VinayDokania']
# Tags --> ['@htTweets']
# Tags --> ['@sanju4odisha']
# Tags --> ['@KhushiKadri']
# Tags --> ['@Niteshs32113187', '@ANI']
# Tags --> ['@shefali_bagga']
# Tags --> ['@HCookey']
# Tags --> ['@georgian_mayank']
# Tags --> ['@rayonkiran29', '@narendramodi']
# None
# Tags --> ['@georgian_mayank']
# Tags --> ['@rajeev_mp']
# Tags --> ['@VinayDokania']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@moneycontrolcom']
# None
# Tags --> ['@moneycontrolcom']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@FinancialReview', '@LiberalAus', '@JulieBishopMP', '@andrewtillett']
# Tags --> ['@PankajPachauri']
# Tags --> ['@georgian_mayank']
# Tags --> ['@sonalkalra']
# Tags --> ['@sonalkalra']
# Tags --> ['@RamMNK']
# Tags --> ['@inecnigeria']
# Tags --> ['@sanju4odisha']
# Tags --> ['@Awhadspeaks']
# Tags --> ['@voiceofnigeria']
# None
# Tags --> ['@saviour_era', '@loksabhatv']
# Tags --> ['@georgian_mayank']
# Tags --> ['@VinayDokania']
# Tags --> ['@satishniti']
# Tags --> ['@ThumaFoundation']
# Tags --> ['@ETMarkets']
# Tags --> ['@htTweets']
# Tags --> ['@sanju4odisha']
# Tags --> ['@MahimaShastri']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@MaheshBhatt2016', '@narendramodi']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@KhushiKadri']
# Tags --> ['@sanju4odisha']
# None
# None
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@TimesNow']
# Tags --> ['@rahulkpopat']
# Tags --> ['@rajeev_mp']
# Tags --> ['@loksabhatv']
# Tags --> ['@KhajuriaManu']
# Tags --> ['@NehruKiGalti_']
# Tags --> ['@georgian_mayank']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@PankajPachauri']
# Tags --> ['@VinayDokania']
# Tags --> ['@s_anuj']
# Tags --> ['@otvnews']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@SABCNewsOnline']
# Tags --> ['@drabhishekjain', '@DXPAssociation', '@SushmaSwaraj', '@nitin_gadkari', '@arunjaitley', '@ArvindKejriwal', '@SatyendarJain', '@mlkhattar', '@Rao_InderjitS', '@Rao']
# Tags --> ['@MahimaShastri']
# Tags --> ['@georgian_mayank']
# Tags --> ['@asadowaisi']
# None
# Tags --> ['@georgian_mayank']
# Tags --> ['@iankit07', '@narendramodi', '@narendramodi']
# Tags --> ['@MahimaShastri']
# Tags --> ['@iankit07', '@narendramodi', '@narendramodi']
# Tags --> ['@india_rising95']
# Tags --> ['@iankit07', '@BJP4Karnataka']
# Tags --> ['@HCookey']
# Tags --> ['@Pavansai_15', '@ysjagan', '@ncbn', '@PawanKalyan', '@SakshiHDTV', '@TV9Telugu', '@nt']
# Tags --> ['@ThumaFoundation']
# Tags --> ['@MahimaShastri']
# Tags --> ['@Lakshmi02461825']
# None
# Tags --> ['@upma23', '@newagesong', '@ANI']
# Tags --> ['@CongressSevadal']
# Tags --> ['@AbdulBa33898424']
# Tags --> ['@ASTanwar10']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@sagenaradamuni']
# Tags --> ['@HCookey']
# Tags --> ['@rightlog_in']
# Tags --> ['@HCookey']
# Tags --> ['@georgian_mayank']
# Tags --> ['@PankajPachauri']
# Tags --> ['@pduggal139', '@narendramodi', '@RahulGandhi']
# Tags --> ['@GovernmentZA']
# Tags --> ['@MahimaShastri']
# None
# None
# None
# Tags --> ['@pawan26kpareek']
# Tags --> ['@BurnolReloaded', '@narendramodi']
# Tags --> ['@sudarsansand']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@Khannasaahab']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@sudarsansand']
# Tags --> ['@sonalkalra']
# Tags --> ['@GoNews24x7', '@PankajPachauri']
# Tags --> ['@georgian_mayank']
# Tags --> ['@georgian_mayank']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@PankajPachauri']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@sanju4odisha']
# None
# Tags --> ['@iankit07', '@narendramodi', '@narendramodi']
# Tags --> ['@georgian_mayank']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@PankajPachauri']
# None
# None
# Tags --> ['@moneycontrolcom']
# None
# Tags --> ['@NeedhiMurasu', '@narendramodi']
# Tags --> ['@sudarsansand']
# Tags --> ['@MzwaneleManyi', '@MbalulaFikile']
# Tags --> ['@SABCNewsOnline']
# Tags --> ['@narendramodi']
# None
# Tags --> ['@SABCNewsOnline']
# None
# Tags --> ['@KhushiKadri']
# Tags --> ['@srivatsayb']
# Tags --> ['@siddaramaiah']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@iankit07', '@narendramodi']
# Tags --> ['@BloombergQuint']
# Tags --> ['@siddaramaiah', '@RahulGandhi', '@narendramodi']
# None
# Tags --> ['@SABCNewsOnline']
# Tags --> ['@CongressSevadal']
# Tags --> ['@VinayDokania']
# Tags --> ['@KhushiKadri']
# Tags --> ['@sudarsansand']
# Tags --> ['@VinayDokania']
# Tags --> ['@sagenaradamuni']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@KhushiKadri']
# Tags --> ['@VinayDokania']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@seoarticles7']
# Tags --> ['@vjitu24', '@timesofindia']
# Tags --> ['@SudhinBhadoria']
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# Tags --> ['@timesofindia']
# None
# Tags --> ['@AIT_Online']
# Tags --> ['@icrao', '@TimesNowHindi', '@narendramodi']
# Tags --> ['@SABCNewsOnline']
# Tags --> ['@icrao', '@TimesNowHindi', '@narendramodi']
# Tags --> ['@RoposoLove']
# Tags --> ['@SirPareshRawal', '@sardesairajdeep']
# Tags --> ['@rahulkpopat']
# Tags --> ['@VinayDokania']
# Tags --> ['@DKhantastic']
# Tags --> ['@GovUmarGanduje']
# Tags --> ['@Sahastrabuddhhe']
# Tags --> ['@KhushiKadri']
# Tags --> ['@AIADMKOfficial']
# Tags --> ['@SABCNewsOnline']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@narendramodi', '@RahulGandhi', '@ncbn', '@ArvindKejriwal', '@MamataOfficial']
# Tags --> ['@legend_celeb']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@PavanOfficiall', '@JanaSenaParty']
# Tags --> ['@VinayDokania']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@the_hindu']
# Tags --> ['@OfficialPDPNig', '@MBuhari']
# None
# Tags --> ['@the_hindu']
# None
# None
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@MahimaShastri']
# Tags --> ['@cchandramouli1']
# Tags --> ['@PplOfIndia', '@AdityaMenon22']
# Tags --> ['@VinayDokania']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@rajeev_mp']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@moneycontrolcom']
# Tags --> ['@the_hindu']
# Tags --> ['@RoposoLove']
# Tags --> ['@YSRCParty']
# Tags --> ['@CNBCTV18News']
# Tags --> ['@keyakahe', '@tehseenp']
# Tags --> ['@KhushiKadri']
# Tags --> ['@Aabhas24']
# Tags --> ['@RoposoLove']
# Tags --> ['@RoposoLove']
# None
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@Aabhas24']
# Tags --> ['@aftabmrz007']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@rao_nava']
# Tags --> ['@BabuSaheb90']
# Tags --> ['@Mahdie_pop']
# Tags --> ['@VinayDokania']
# Tags --> ['@imanojprabakar']
# Tags --> ['@Gupta_vijender']
# Tags --> ['@MahimaShastri']
# Tags --> ['@KarthikWarriyar', '@OmarAbdullah', '@MehboobaMufti']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@sudarsansand']
# None
# None
# Tags --> ['@Who_Kajal']
# None
# Tags --> ['@VinayDokania']
# None
# None
# Tags --> ['@BTVI', '@VinodSharmaView']
# Tags --> ['@rajeev_mp']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@VinayDokania']
# None
# Tags --> ['@georgian_mayank']
# Tags --> ['@AKYOnline']
# Tags --> ['@PavanOfficiall', '@JanaSenaParty']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@rayonkiran29', '@narendramodi']
# None
# Tags --> ['@shefali_bagga']
# None
# Tags --> ['@VinayDokania']
# Tags --> ['@ManiDevaMS']
# None
# Tags --> ['@HCookey']
# Tags --> ['@TendulkarRoger']
# Tags --> ['@SiDManchikanti', '@PawanKalyan', '@JanaSenaParty']
# Tags --> ['@MaximeDeepa', '@BJP4India']
# Tags --> ['@VinayDokania']
# Tags --> ['@Donvoegt']
# Tags --> ['@KhushiKadri']
# Tags --> ['@KhushiKadri']
# Tags --> ['@sanjaypaswanbjp']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@heeraman98', '@vivekagnihotri']
# Tags --> ['@rao_nava']
# Tags --> ['@OmarAbdullah', '@MehboobaMufti']
# Tags --> ['@inecnigeria']
# Tags --> ['@VinayDokania']
# Tags --> ['@scpatodia', '@theicai']
# Tags --> ['@KhushiKadri']
# Tags --> ['@KhushiKadri']
# Tags --> ['@ManviDad']
# Tags --> ['@Gursatinder68', '@sardesairajdeep', '@narendramodi', '@DailyO_']
# Tags --> ['@AmbVPrakash']
# None
# Tags --> ['@rao_nava']
# Tags --> ['@frankdonga_']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@KhushiKadri']
# Tags --> ['@TrendPSPK', '@PawanKalyan']
# Tags --> ['@SudhinBhadoria']
# Tags --> ['@VinayDokania']
# Tags --> ['@SudarshanNewsTV', '@KhanAmanatullah']
# Tags --> ['@TimesNowHindi', '@narendramodi']
# Tags --> ['@VinayDokania']
# Tags --> ['@AmbVPrakash']
# Tags --> ['@aftabmrz007']
# Tags --> ['@sudarsansand']
# Tags --> ['@BTVI', '@VinodSharmaView']
# Tags --> ['@SamarAn47896449']
# Tags --> ['@MahimaShastri']
# Tags --> ['@HerrBains']
# Tags --> ['@yadavakhilesh']
# Tags --> ['@CongressSevadal']
# Tags --> ['@RameshYouth']
# Tags --> ['@MahimaShastri']
# Tags --> ['@VinodSharmaView']
# Tags --> ['@Zebaism', '@Jairam_Ramesh']
# Tags --> ['@MahimaShastri']
# Tags --> ['@HCookey']
# Tags --> ['@rajeev_mp']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@KhushiKadri']
# Tags --> ['@KhushiKadri']
# Tags --> ['@MahimaShastri']
# Tags --> ['@india_rising95']
# Tags --> ['@sudarsansand']
# Tags --> ['@its_skp', '@BJP4India']
# Tags --> ['@MahimaShastri']
# Tags --> ['@news18dotcom']
# Tags --> ['@Donvoegt']
# None
# Tags --> ['@Awhadspeaks']
# Tags --> ['@Jairam_Ramesh']
# Tags --> ['@aftabmrz007']
# Tags --> ['@girishchawla', '@AnkitLal']
# Tags --> ['@RubeenaJan1']
# Tags --> ['@frankdonga_']
# Tags --> ['@CTRavi_BJP']
# None
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@georgian_mayank']
# Tags --> ['@KhushiKadri']
# Tags --> ['@rahulkpopat']
# None
# Tags --> ['@rahulkpopat']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@ManiDevaMS']
# Tags --> ['@sudarsansand']
# Tags --> ['@TendulkarRoger']
# Tags --> ['@georgian_mayank']
# Tags --> ['@prasannavishy', '@swarajyamag']
# Tags --> ['@KhushiKadri']
# Tags --> ['@VinayDokania']
# Tags --> ['@georgian_mayank']
# Tags --> ['@UrSaiSrujan108']
# Tags --> ['@rahulkpopat']
# Tags --> ['@georgian_mayank']
# Tags --> ['@sudarsansand']
# Tags --> ['@htTweets']
# Tags --> ['@sudarsansand']
# Tags --> ['@Anirudh_Astro']
# Tags --> ['@satishniti']
# Tags --> ['@KhushiKadri']
# Tags --> ['@aimim_national', '@asadowaisi']
# None
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# None
# None
# Tags --> ['@news18dotcom']
# Tags --> ['@georgian_mayank']
# Tags --> ['@georgian_mayank']
# Tags --> ['@MahimaShastri']
# Tags --> ['@pGurus1']
# Tags --> ['@SINGHRAJIVRANA1']
# Tags --> ['@CTRavi_BJP']
# Tags --> ['@sanju4odisha']
# Tags --> ['@KhushiKadri']
# Tags --> ['@Aabhas24']
# Tags --> ['@georgian_mayank']
# Tags --> ['@VinayDokania']
# Tags --> ['@KhushiKadri']
# Tags --> ['@rayonkiran29', '@narendramodi']
# Tags --> ['@HCookey']
# Tags --> ['@ASTanwar10']
# Tags --> ['@SINGHRAJIVRANA1']
# Tags --> ['@georgian_mayank']
# Tags --> ['@KhanAmanatullah', '@ArvindKejriwal']
# Tags --> ['@rahulkpopat']
# Tags --> ['@georgian_mayank']
# ...
# None
# Tags --> ['@Aryanwarlord']
# Tags --> ['@joerave']
# None
# Tags --> ['@TitusMatlawe', '@KarimaBrown']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@SupriyaShrinate']
# Tags --> ['@william81croix', '@CTVNews']
# Tags --> ['@jamesstyan']
# Tags --> ['@CTVNews']
# Tags --> ['@imanojprabakar']
# Tags --> ['@imanojprabakar']
# Tags --> ['@JhaSanjay', '@BJP4India', '@INCIndia']
# Tags --> ['@Aryanwarlord']
# None
# None
# Tags --> ['@kushalpathak']
# Tags --> ['@GauPrem']
# Tags --> ['@Aryanwarlord']
# Tags --> ['@joerave']
# Tags --> ['@GauPrem']
# Tags --> ['@GauPrem']
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@joerave']
# None
# Tags --> ['@GauPrem']
# None
# Tags --> ['@joerave']
# Tags --> ['@voiceofnigeria']
# Tags --> ['@shekharkahin', '@aajtak']
# Tags --> ['@GauPrem']
# Tags --> ['@CinemaPichhi']
# Tags --> ['@ThePulse_in']
# Tags --> ['@aajtak']
# Tags --> ['@GauPrem']
# Tags --> ['@kushalpathak']
# None
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@DeeptiSachdeva_']
# None
# None
# Tags --> ['@Siba_TNIE', '@Naveen_Odisha', '@NewIndianXpress']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@SociallyBlog']
# None
# Tags --> ['@OriginalAnmol']
# Tags --> ['@voiceofnigeria']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# None
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@imanojprabakar']
# None
# None
# Tags --> ['@imanojprabakar']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@frankdonga_']
# None
# None
# None
# Tags --> ['@pawan26kpareek']
# Tags --> ['@Aryanwarlord']
# Tags --> ['@ClassIbadan', '@DownloaderBot']
# Tags --> ['@joerave']
# Tags --> ['@ThePulse_in']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@TheNationNews']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@BloombergQuint']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@pradip103']
# Tags --> ['@CinemaPichhi']
# Tags --> ['@ClassIbadan']
# None
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@narendramodi']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@OriginalAnmol']
# None
# None
# Tags --> ['@937RhythmFm', '@KunleAwosiyan']
# None
# Tags --> ['@OriginalAnmol']
# None
# None
# Tags --> ['@iAbrahamC']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@TheNationNews']
# None
# None
# Tags --> ['@TheNationNews']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@OriginalAnmol']
# None
# Tags --> ['@CinemaPichhi']
# Tags --> ['@LukakuNaija']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@DC_Ranchi']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# None
# Tags --> ['@937RhythmFm', '@KunleAwosiyan']
# None
# Tags --> ['@satishniti']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@CinemaPichhi']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@City_Press', '@RapuleT']
# Tags --> ['@NFP_Party', '@NFP_Party']
# Tags --> ['@TheNationNews']
# None
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# None
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@GomatiSivam']
# None
# Tags --> ['@TheNationNews']
# None
# Tags --> ['@TheNationNews']
# Tags --> ['@TheNationNews']
# Tags --> ['@TheNationNews']
# Tags --> ['@OriginalAnmol', '@BJP4India']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@imanojprabakar']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@ANI']
# None
# None
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# None
# None
# None
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@iambolar']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@ShekharGupta', '@DeShobhaa']
# Tags --> ['@danielamicheal', '@SituationRoomNg', '@PLACNG', '@inecnigeria', '@YIAGA', '@EiENigeria', '@cleenfoundation', '@CDDWestAfrica', '@thecableng', '@SDNNigerDelta', '@KD']
# Tags --> ['@frankdonga_']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@pradip103']
# Tags --> ['@TheNationNews']
# Tags --> ['@pradip103']
# None
# Tags --> ['@Reshu61686527', '@BJP4UP', '@narendramodi', '@PKumar59', '@myogia']
# None
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@SituationRoomNg', '@PLACNG', '@inecnigeria', '@YIAGA', '@EiENigeria', '@cleenfoundation', '@CDDWestAfrica', '@thecableng', '@SDNNigerDelta']
# Tags --> ['@937RhythmFm', '@KunleAwosiyan']
# None
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@TheNationNews']
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# None
# None
# None
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# None
# Tags --> ['@frankdonga_']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@NairShilpa1308']
# None
# Tags --> ['@narendramodi', '@BJP4India']
# Tags --> ['@jankibaat1', '@pradip103']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@maiamofficial']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@frankdonga_']
# Tags --> ['@ClassIbadan']
# Tags --> ['@MYANC']
# None
# Tags --> ['@NairShilpa1308']
# Tags --> ['@937RhythmFm', '@KunleAwosiyan']
# Tags --> ['@OriginalAnmol']
# None
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# None
# Tags --> ['@ParthaBezbar']
# Tags --> ['@prettykollywood']
# Tags --> ['@Duke_Joansean']
# Tags --> ['@_umakantsingh', '@narendramodi_in']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@TheCitizen_in']
# Tags --> ['@narendramodi_in']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@kushalpathak']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@BurnolReloaded']
# Tags --> ['@pradip103']
# Tags --> ['@Reshu61686527', '@BJP4UP', '@narendramodi', '@PKumar59', '@myogia']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@ThePulse_in']
# Tags --> ['@ThePulse_in']
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@937RhythmFm', '@KunleAwosiyan']
# Tags --> ['@Manesha76']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# None
# Tags --> ['@ghanshyamtiwari', '@yadavakhilesh']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@ThePulse_in']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@SupriyaShrinate']
# Tags --> ['@ThePulse_in']
# None
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@ThePulse_in']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@ThePulse_in']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@OriginalAnmol']
# None
# None
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@yadavakhilesh']
# Tags --> ['@Glocalbrandsng']
# Tags --> ['@ThePulse_in']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@AskGregory']
# Tags --> ['@ThePulse_in']
# Tags --> ['@ThePulse_in']
# None
# Tags --> ['@pradip103', '@PMOIndia', '@narendramodi']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@ThePulse_in']
# Tags --> ['@puneetshukla3', '@News18India', '@ReporterVikrant', '@ARPITAARYA']
# Tags --> ['@ThePulse_in']
# Tags --> ['@NairShilpa1308']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@PINDFoundation']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@ThePulse_in']
# None
# Tags --> ['@SAMsHowitzer']
# None
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@ThePulse_in']
# Tags --> ['@SwachchhasilaB']
# Tags --> ['@ThePulse_in']
# Tags --> ['@Duke_Joansean']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@ThePulse_in']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@ThePulse_in']
# None
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@PawarSpeaks']
# Tags --> ['@jankibaat1', '@pradip103']
# Tags --> ['@ThePulse_in']
# Tags --> ['@pradip103']
# Tags --> ['@Reshu61686527', '@BJP4UP', '@narendramodi', '@PKumar59', '@myogia']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@NairShilpa1308']
# None
# Tags --> ['@pawan26kpareek']
# Tags --> ['@SociallyBlog']
# Tags --> ['@SociallyBlog', '@TwitterIndia']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@MYP_ORG']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@TheCitizen_in']
# Tags --> ['@OriginalAnmol']
# None
# None
# Tags --> ['@OriginalAnmol']
# Tags --> ['@balbir59', '@BJP4India']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@ThePulse_in']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@pawan26kpareek']
# None
# Tags --> ['@jskeshriya', '@narendramodi', '@RahulGandhi', '@PawarSpeaks', '@Dev_Fadnavis', '@uddhavthackeray', '@RajThackeray', '@jskeshriya']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@kushalpathak']
# Tags --> ['@IronuaMichelle']
# Tags --> ['@KapilSibal']
# Tags --> ['@Reshu61686527', '@BJP4UP', '@narendramodi', '@PKumar59', '@myogia']
# Tags --> ['@5pm']
# Tags --> ['@RahulGandhi', '@narendramodi']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@OriginalAnmol']
# None
# Tags --> ['@ewnupdates', '@IFPinParliament']
# Tags --> ['@kharabelaswain', '@BJP4India', '@BJP4Odisha', '@ArunSinghbjp', '@PandaJay', '@AmitShah']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@AmilwithanL']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@BloombergQuint']
# Tags --> ['@frankdonga_']
# Tags --> ['@OriginalAnmol']
# None
# Tags --> ['@OriginalAnmol']
# Tags --> ['@Tracybashful']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@being_delhite']
# Tags --> ['@thedailyvox']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@pradip103']
# Tags --> ['@iAbrahamC']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@OriginalAnmol']
# Tags --> ['@ikamalhaasan']
# Tags --> ['@Milan_reports']
# None
# Tags --> ['@BurnolReloaded']
# None
# Tags --> ['@pradip103']
# Tags --> ['@frankdonga_']
# Tags --> ['@SAMsHowitzer']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@TweetNitinS', '@SpokespersonECI']
# Tags --> ['@KananRanjit']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@tweetsakshi']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@being_delhite']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@drabhishekjain', '@MOHIndia', '@nitin_gadkari', '@OfficeOfNG', '@NHAISocialmedia', '@ArvindKejriwal', '@AAPDelhi', '@LtGovDelhi']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@iAbrahamC']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@pradip103', '@PMOIndia', '@narendramodi']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@OriginalAnmol']
# None
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@SSanyal', '@IndiaAheadNews', '@sanket', '@Sanakhan_m', '@jujharsingh111', '@SSanyal']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@being_delhite']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@pankajbhatt54', '@vivekkapoor111', '@yviren', '@AmitShah', '@narendramodi', '@PMOIndia', '@SecretaryDEA', '@realDonaldTrump', '@POTUS', '@FLOTUS', '@WhiteHouse', '@Sus']
# Tags --> ['@KSeriake']
# Tags --> ['@_KulwantDSingh', '@SaintRampalJiM']
# Tags --> ['@KSeriake']
# Tags --> ['@pradip103']
# Tags --> ['@OriginalAnmol']
# None
# Tags --> ['@OriginalAnmol']
# Tags --> ['@DeeptiSachdeva_']
# None
# Tags --> ['@Siba_TNIE', '@Naveen_Odisha', '@NewIndianXpress']
# Tags --> ['@SaintRampalJiM']
# None
# Tags --> ['@voiceofnigeria']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@CMO_Odisha', '@Naveen_Odisha']
# Tags --> ['@Naveen_Odisha']
# Tags --> ['@iambolar']
# None
# Tags --> ['@ThePulse_in']
# Tags --> ['@pradip103']
# Tags --> ['@DeeptiSachdeva_']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@pradip103']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@frankdonga_']
# Tags --> ['@frankdonga_']
# Tags --> ['@voiceofnigeria']
# Tags --> ['@SahleWorkZewde']
# Tags --> ['@sardesairajdeep', '@iankusharoraa']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@prettykollywood']
# Tags --> ['@RahulGandhi']
# None
# Tags --> ['@Naveen_Odisha', '@NewIndianXpress']
# Tags --> ['@SSanyal', '@IndiaAheadNews', '@sanket', '@Sanakhan_m', '@jujharsingh111', '@SSanyal']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@OriginalAnmol']
# None
# None
# Tags --> ['@MYANC']
# None
# None
# Tags --> ['@KiranGhosh20']
# Tags --> ['@pradip103']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@BurnolReloaded']
# None
# Tags --> ['@pradip103', '@PMOIndia', '@narendramodi']
# Tags --> ['@IndiaAheadNews', '@sanket', '@Sanakhan_m', '@jujharsingh111']
# Tags --> ['@puneetshukla3', '@News18India', '@ReporterVikrant', '@ARPITAARYA']
# Tags --> ['@aacparty', '@inecnigeria', '@SaharaReporters', '@aacparty']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@sumanthraman']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@pradip103']
# Tags --> ['@pradip103']
# Tags --> ['@puneetshukla3', '@News18India', '@ReporterVikrant', '@ARPITAARYA']
# Tags --> ['@YouthRisingNG']
# Tags --> ['@puneetshukla3', '@News18India', '@ReporterVikrant', '@ARPITAARYA']
# None
# Tags --> ['@KiratLalla', '@MzwaneleManyi', '@ATMovement_SA']
# None
# Tags --> ['@pradip103', '@PMOIndia', '@narendramodi']
# Tags --> ['@jankibaat1', '@pradip103']
# None
# Tags --> ['@sardesairajdeep']
# None
# Tags --> ['@frankdonga_']
# Tags --> ['@pradip103', '@PMOIndia', '@narendramodi']
# Tags --> ['@pradip103']
# Tags --> ['@abpmajhatv', '@Marathi_Rash', '@mnsadhikrut', '@RajThackeray', '@NCPspeaks', '@PawarSpeaks']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@pradip103']
# Tags --> ['@BurnolReloaded']
# Tags --> ['@NairShilpa1308']
# None
# Tags --> ['@pawan26kpareek']
# Tags --> ['@KatMinikatv8', '@Bowenchris', '@JoshFrydenberg', '@billshortenmp', '@ALeighMP']
# None
# Tags --> ['@News18India', '@ReporterVikrant', '@ARPITAARYA']
# None
# Tags --> ['@pawan26kpareek']
# Tags --> ['@balbir59', '@BJP4India']
# Tags --> ['@lpsahi', '@ShashiTharoor']
# Tags --> ['@mnsadhikrut']
# Tags --> ['@rameshlaus']
# Tags --> ['@RishhShuklabjp']
# Tags --> ['@nolom', '@Sun']
# Tags --> ['@pradip103']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@TheNationNews']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@SaintOraye', '@HQNigerianArmy', '@nassnigeria']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@pankajbhatt54', '@vivekkapoor111', '@yviren', '@AmitShah', '@narendramodi', '@PMOIndia', '@SecretaryDEA', '@realDonaldTrump', '@POTUS', '@FLOTUS', '@WhiteHouse', '@Sus']
# Tags --> ['@nolom', '@Sun']
# None
# Tags --> ['@dhanyarajendran', '@rsponnathpur']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@frankdonga_']
# None
# Tags --> ['@OriginalAnmol']
# Tags --> ['@pradip103']
# Tags --> ['@CinemaPichhi']
# Tags --> ['@KatMinikatv8', '@Bowenchris', '@JoshFrydenberg', '@billshortenmp', '@ALeighMP']
# Tags --> ['@TweetNitinS', '@SpokespersonECI']
# Tags --> ['@sumanthraman']
# Tags --> ['@BurnolReloaded']
# Tags --> ['@pankajbhatt54', '@vivekkapoor111', '@yviren', '@AmitShah', '@narendramodi', '@PMOIndia', '@SecretaryDEA', '@realDonaldTrump', '@POTUS', '@FLOTUS', '@WhiteHouse', '@Sus']
# Tags --> ['@NairShilpa1308']
# Tags --> ['@pradip103']
# Tags --> ['@BurnolReloaded']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@nassnigeria']
# Tags --> ['@AskGregory']
# Tags --> ['@OriginalAnmol']
# Tags --> ['@pradip103']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@rsponnathpur']
# Tags --> ['@pawan26kpareek']
# Tags --> ['@pradip103']
# Tags --> ['@pradip103']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']
# Tags --> ['@nistula', '@Naveen_Odisha', '@bjd_odisha']

# %%
df.head()
# Out:
#                                                Tweet        Date      time  \
# 0   @arpitajtweets: Just for fun\xf0\x9f\x91\x8d\...  2019-03-10  07:52:48
# 1  Where is safety,how we safe,this is the situat...  2019-03-10  07:52:48
# 2   @ManiDevaMS: #DelhiCapitals is not only #indi...  2019-03-10  07:52:48
# 3   @VinayDokania: How Indian Journalists come ou...  2019-03-10  07:52:48
# 4  #Elections2019 Dates are finally out. @BoredBr...  2019-03-10  07:52:48
#
#   Tweet_type                                          hash_tags  \
# 0         RT                 [#MondayMotivaton, #Elections2019]
# 1          T      [#India, #ElectionCommission, #Elections2019]
# 2         RT  [#DelhiCapitals, #india, #raped, #TamilNadu, #...
# 3         RT                     [#OpinionPoll, #Elections2019]
# 4          T                                   [#Elections2019]
#
#                                      user_tags
# 0  [@arpitajtweets, @narendramodi, @BJP4India]
# 1                                         None
# 2                                [@ManiDevaMS]
# 3                              [@VinayDokania]
# 4                              [@BoredBroacha]

# %%
for i in range(0,len(df['Tweet'])):
    #Removing special characters from tweets
    df["Tweet"][i] = re.sub(r"[^a-zA-Z0-9]+", ' ', df['Tweet'][i])

# %%
df['Tweet'].head()
# Out:
# 0     arpitajtweets Just for fun xf0 x9f x91 x8d nd...
# 1    Where is safety how we safe this is the situat...
# 2     ManiDevaMS DelhiCapitals is not only india 10...
# 3     VinayDokania How Indian Journalists come out ...
# 4     Elections2019 Dates are finally out BoredBroa...
# Name: Tweet, dtype: object

# %%
for i in range(0,len(df['Tweet'])):
    #Removing numbers from tweets
    df["Tweet"][i] = re.sub("\d+","", df['Tweet'][i])

# %%
df['Tweet'].head()
# Out:
# 0     arpitajtweets Just for fun xf xf x xd ndont t...
# 1    Where is safety how we safe this is the situat...
# 2     ManiDevaMS DelhiCapitals is not only india  o...
# 3     VinayDokania How Indian Journalists come out ...
# 4     Elections Dates are finally out BoredBroacha ...
# Name: Tweet, dtype: object

# %%
for i in range(0,len(df['Tweet'])):
    #Removing all single word characters in a string
    #This includes removing charaters like 'a' and 'I' as they too add no meaning to the sentiments
    df["Tweet"][i] = re.sub(r"\b[a-zA-Z]\b", "", df['Tweet'][i])

# %%
df['Tweet'].head()
# Out:
# 0     arpitajtweets Just for fun xf xf  xd ndont ta...
# 1    Where is safety how we safe this is the situat...
# 2     ManiDevaMS DelhiCapitals is not only india  o...
# 3     VinayDokania How Indian Journalists come out ...
# 4     Elections Dates are finally out BoredBroacha ...
# Name: Tweet, dtype: object

# %%
df.head()
# Out:
#                                                Tweet        Date      time  \
# 0   arpitajtweets Just for fun xf xf  xd ndont ta...  2019-03-10  07:52:48
# 1  Where is safety how we safe this is the situat...  2019-03-10  07:52:48
# 2   ManiDevaMS DelhiCapitals is not only india  o...  2019-03-10  07:52:48
# 3   VinayDokania How Indian Journalists come out ...  2019-03-10  07:52:48
# 4   Elections Dates are finally out BoredBroacha ...  2019-03-10  07:52:48
#
#   Tweet_type                                          hash_tags  \
# 0         RT                 [#MondayMotivaton, #Elections2019]
# 1          T      [#India, #ElectionCommission, #Elections2019]
# 2         RT  [#DelhiCapitals, #india, #raped, #TamilNadu, #...
# 3         RT                     [#OpinionPoll, #Elections2019]
# 4          T                                   [#Elections2019]
#
#                                      user_tags
# 0  [@arpitajtweets, @narendramodi, @BJP4India]
# 1                                         None
# 2                                [@ManiDevaMS]
# 3                              [@VinayDokania]
# 4                              [@BoredBroacha]

# %% [markdown]
# ### 1.6 Further Scope
# - `The data is now clean but can be cleaned even more try to come up with your own ideas as of what else can be done to the data`
# - `The data can be used for sentiment analysis, Emotion Analysis, Action Analysis, Topic modelling and What not?`
# - `The beauty of REGEX is that the functions are exchangable, try achieving the steps using different Regular Expressions`

# %% [markdown]
# ### 1.7 Some successful Early NLP Systems
# - ELIZA (WEIZENBAUM 1966)
# - SysTran (System Translation 1969)
# - SHRDLU (Winogard 1972)
# - LUNAR (Woods 1977)
